# %% [markdown]
# # MobileNetV2 Feature Extraction
#
# Transfer Learning with Keras and Deep Learning
# https://pyimagesearch.com/2019/05/20/transfer-learning-with-keras-and-deep-learning/
#
# Keras: Feature extraction on large datasets with Deep Learning
# https://pyimagesearch.com/2019/05/27/keras-feature-extraction-on-large-datasets-with-deep-learning/

# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import pickle
from imutils import paths

import tensorflow as tf
from tensorflow import keras 
from keras.models import Model
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from sklearn.preprocessing import LabelEncoder, LabelBinarizer
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split
from tqdm.notebook import tqdm

import warnings
warnings.filterwarnings("ignore")

# %%
## path to image dataset
BASE_DIR = "C:/Users/noqui/Desktop/FYP/Work_Folder/dataset/cassava"
TRAIN_DIR = "train"
TEST_DIR = "test"

## path to loading model
MODEL_PATH = "C:/Users/noqui/Desktop/FYP/Work_Folder/output/model"

## output paths
FEATURES_OUTPUT_PATH = "C:/Users/noqui/Desktop/FYP/Work_Folder/output/features"
LE_OUTPUT_PATH = "C:/Users/noqui/Desktop/FYP/Work_Folder/output/encoder"
MODEL_OUTPUT_PATH = "C:/Users/noqui/Desktop/FYP/Work_Folder/output/model"

for path in [FEATURES_OUTPUT_PATH, LE_OUTPUT_PATH, MODEL_OUTPUT_PATH]:
    if not os.path.exists(path):
        os.makedirs(path)
    
## essential parameters
BATCH_SIZE = 32
DIM = (224, 224)

# %% [markdown]
# ## Feature Extraction

# %%
### Function to extract features 
# model        : Keras model for feature extractor
# output_shape : Output shape of the max-pooling layer
# model_name   : Name of the model

def extractFeatures(model, output_shape, model_name):
    le = None
    for split_type in [TRAIN_DIR, TEST_DIR]:

        # grab all image paths in the current path
        print(f"[INFO] processing {split_type} split...")
        path = f"{BASE_DIR}/{split_type}"
        imagePaths = list(paths.list_images(path)) # unlike os.listdir, this grabs all images from subfolders

        # randomly shuffle the image paths and then extract the class
        # labels from the file paths
        labels = [p.split(os.path.sep)[1] for p in imagePaths]
        allFeatures = [] # to be appended
        
        # fit the label encoder once
        if le is None:
            le = LabelEncoder()
            le.fit(labels)

        # loop over the images in batches
        for (b, i) in enumerate(range(0, len(imagePaths), BATCH_SIZE)):
            # extract the batch of images and labels, then initialize the
            # list of actual images that will be passed through the network
            # for feature extraction
            print(f"[INFO] processing batch {b+1}/{int(np.ceil(len(imagePaths) / float(BATCH_SIZE)))}")
            batchPaths = imagePaths[i:i + BATCH_SIZE]
            batchImages = []

            # loop over the images and labels in the current batch
            for imagePath in batchPaths:
                # load the input image using the Keras helper utility
                # while ensuring the image is resized
                image = load_img(imagePath, target_size = DIM) 
                image = img_to_array(image)

                # preprocess the image by 
                # (1) expanding the dimensions and
                # (2) subtracting the mean RGB pixel intensity from the ImageNet dataset
                image = np.expand_dims(image, axis = 0)
                image = preprocess_input(image)

                # add the image to the batch
                batchImages.append(image)

            # pass the images through the network and use the outputs as
            # our actual features, then reshape the features into a flattened volume
            batchImages = np.vstack(batchImages)
            features = model.predict(batchImages, batch_size = BATCH_SIZE)
            features = features.reshape((features.shape[0], output_shape))
            
            # append features
            for vec in features:
                allFeatures.append(vec)
        
        allFeatures = np.array(allFeatures)
        labels = np.array(labels)
        
        # dump features, labels, and imagePaths
        pickle.dump(allFeatures, open(f"{FEATURES_OUTPUT_PATH}/{model_name.lower()}_{split_type}_features.pkl", "wb"))
        pickle.dump(labels, open(f"{FEATURES_OUTPUT_PATH}/{model_name.lower()}_{split_type}_labels.pkl", "wb"))
        pickle.dump(imagePaths,  open(f"{FEATURES_OUTPUT_PATH}/{model_name.lower()}_{split_type}_imagepaths.pkl", "wb"))

    # serialize the label encoder to disk
    pickle.dump(le, open(f"{LE_OUTPUT_PATH}/encoder.pkl", "wb"))

# %%
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input

# MobileNetV2 with imagenet as weights
mobilenetv2_imagenet_fe = MobileNetV2(weights = "imagenet", input_shape = (224, 224, 3), include_top = False)
mobilenetv2_imagenet_fe.trainable = True
mobilenetv2_imagenet_fe.summary()
# Out:
# Model: "mobilenetv2_1.00_224"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  Conv1 (Conv2D)                 (None, 112, 112, 32  864         ['input_1[0][0]']
#                                 )
#
#  bn_Conv1 (BatchNormalization)  (None, 112, 112, 32  128         ['Conv1[0][0]']
#                                 )
#
#  Conv1_relu (ReLU)              (None, 112, 112, 32  0           ['bn_Conv1[0][0]']
#                                 )
#
#  expanded_conv_depthwise (Depth  (None, 112, 112, 32  288        ['Conv1_relu[0][0]']
#  wiseConv2D)                    )
#
#  expanded_conv_depthwise_BN (Ba  (None, 112, 112, 32  128        ['expanded_conv_depthwise[0][0]']
#  tchNormalization)              )
#
#  expanded_conv_depthwise_relu (  (None, 112, 112, 32  0          ['expanded_conv_depthwise_BN[0][0
#  ReLU)                          )                                ]']
#
#  expanded_conv_project (Conv2D)  (None, 112, 112, 16  512        ['expanded_conv_depthwise_relu[0]
#                                 )                                [0]']
#
#  expanded_conv_project_BN (Batc  (None, 112, 112, 16  64         ['expanded_conv_project[0][0]']
#  hNormalization)                )
#
#  block_1_expand (Conv2D)        (None, 112, 112, 96  1536        ['expanded_conv_project_BN[0][0]'
#                                 )                                ]
#
#  block_1_expand_BN (BatchNormal  (None, 112, 112, 96  384        ['block_1_expand[0][0]']
#  ization)                       )
#
#  block_1_expand_relu (ReLU)     (None, 112, 112, 96  0           ['block_1_expand_BN[0][0]']
#                                 )
#
#  block_1_pad (ZeroPadding2D)    (None, 113, 113, 96  0           ['block_1_expand_relu[0][0]']
#                                 )
#
#  block_1_depthwise (DepthwiseCo  (None, 56, 56, 96)  864         ['block_1_pad[0][0]']
#  nv2D)
#
#  block_1_depthwise_BN (BatchNor  (None, 56, 56, 96)  384         ['block_1_depthwise[0][0]']
#  malization)
#
#  block_1_depthwise_relu (ReLU)  (None, 56, 56, 96)   0           ['block_1_depthwise_BN[0][0]']
#
#  block_1_project (Conv2D)       (None, 56, 56, 24)   2304        ['block_1_depthwise_relu[0][0]']
#
#  block_1_project_BN (BatchNorma  (None, 56, 56, 24)  96          ['block_1_project[0][0]']
#  lization)
#
#  block_2_expand (Conv2D)        (None, 56, 56, 144)  3456        ['block_1_project_BN[0][0]']
#
#  block_2_expand_BN (BatchNormal  (None, 56, 56, 144)  576        ['block_2_expand[0][0]']
#  ization)
#
#  block_2_expand_relu (ReLU)     (None, 56, 56, 144)  0           ['block_2_expand_BN[0][0]']
#
#  block_2_depthwise (DepthwiseCo  (None, 56, 56, 144)  1296       ['block_2_expand_relu[0][0]']
#  nv2D)
#
#  block_2_depthwise_BN (BatchNor  (None, 56, 56, 144)  576        ['block_2_depthwise[0][0]']
#  malization)
#
#  block_2_depthwise_relu (ReLU)  (None, 56, 56, 144)  0           ['block_2_depthwise_BN[0][0]']
#
#  block_2_project (Conv2D)       (None, 56, 56, 24)   3456        ['block_2_depthwise_relu[0][0]']
#
#  block_2_project_BN (BatchNorma  (None, 56, 56, 24)  96          ['block_2_project[0][0]']
#  lization)
#
#  block_2_add (Add)              (None, 56, 56, 24)   0           ['block_1_project_BN[0][0]',
#                                                                   'block_2_project_BN[0][0]']
#
#  block_3_expand (Conv2D)        (None, 56, 56, 144)  3456        ['block_2_add[0][0]']
#
#  block_3_expand_BN (BatchNormal  (None, 56, 56, 144)  576        ['block_3_expand[0][0]']
#  ization)
#  block_3_expand_relu (ReLU)     (None, 56, 56, 144)  0           ['block_3_expand_BN[0][0]']
#
#  block_3_pad (ZeroPadding2D)    (None, 57, 57, 144)  0           ['block_3_expand_relu[0][0]']
#
#  block_3_depthwise (DepthwiseCo  (None, 28, 28, 144)  1296       ['block_3_pad[0][0]']
#  nv2D)
#
#  block_3_depthwise_BN (BatchNor  (None, 28, 28, 144)  576        ['block_3_depthwise[0][0]']
#  malization)
#
#  block_3_depthwise_relu (ReLU)  (None, 28, 28, 144)  0           ['block_3_depthwise_BN[0][0]']
#
#  block_3_project (Conv2D)       (None, 28, 28, 32)   4608        ['block_3_depthwise_relu[0][0]']
#
#  block_3_project_BN (BatchNorma  (None, 28, 28, 32)  128         ['block_3_project[0][0]']
#  lization)
#
#  block_4_expand (Conv2D)        (None, 28, 28, 192)  6144        ['block_3_project_BN[0][0]']
#
#  block_4_expand_BN (BatchNormal  (None, 28, 28, 192)  768        ['block_4_expand[0][0]']
#  ization)
#
#  block_4_expand_relu (ReLU)     (None, 28, 28, 192)  0           ['block_4_expand_BN[0][0]']
#
#  block_4_depthwise (DepthwiseCo  (None, 28, 28, 192)  1728       ['block_4_expand_relu[0][0]']
#  nv2D)
#
#  block_4_depthwise_BN (BatchNor  (None, 28, 28, 192)  768        ['block_4_depthwise[0][0]']
#  malization)
#
#  block_4_depthwise_relu (ReLU)  (None, 28, 28, 192)  0           ['block_4_depthwise_BN[0][0]']
#
#  block_4_project (Conv2D)       (None, 28, 28, 32)   6144        ['block_4_depthwise_relu[0][0]']
#
#  block_4_project_BN (BatchNorma  (None, 28, 28, 32)  128         ['block_4_project[0][0]']
#  lization)
#
#  block_4_add (Add)              (None, 28, 28, 32)   0           ['block_3_project_BN[0][0]',
#                                                                   'block_4_project_BN[0][0]']
#
#  block_5_expand (Conv2D)        (None, 28, 28, 192)  6144        ['block_4_add[0][0]']
#
#  block_5_expand_BN (BatchNormal  (None, 28, 28, 192)  768        ['block_5_expand[0][0]']
#  ization)
#
#  block_5_expand_relu (ReLU)     (None, 28, 28, 192)  0           ['block_5_expand_BN[0][0]']
#
#  block_5_depthwise (DepthwiseCo  (None, 28, 28, 192)  1728       ['block_5_expand_relu[0][0]']
#  nv2D)
#
#  block_5_depthwise_BN (BatchNor  (None, 28, 28, 192)  768        ['block_5_depthwise[0][0]']
#  malization)
#
#  block_5_depthwise_relu (ReLU)  (None, 28, 28, 192)  0           ['block_5_depthwise_BN[0][0]']
#
#  block_5_project (Conv2D)       (None, 28, 28, 32)   6144        ['block_5_depthwise_relu[0][0]']
#
#  block_5_project_BN (BatchNorma  (None, 28, 28, 32)  128         ['block_5_project[0][0]']
#  lization)
#
#  block_5_add (Add)              (None, 28, 28, 32)   0           ['block_4_add[0][0]',
#                                                                   'block_5_project_BN[0][0]']
#
#  block_6_expand (Conv2D)        (None, 28, 28, 192)  6144        ['block_5_add[0][0]']
#
#  block_6_expand_BN (BatchNormal  (None, 28, 28, 192)  768        ['block_6_expand[0][0]']
#  ization)
#
#  block_6_expand_relu (ReLU)     (None, 28, 28, 192)  0           ['block_6_expand_BN[0][0]']
#
#  block_6_pad (ZeroPadding2D)    (None, 29, 29, 192)  0           ['block_6_expand_relu[0][0]']
#
#  block_6_depthwise (DepthwiseCo  (None, 14, 14, 192)  1728       ['block_6_pad[0][0]']
#  nv2D)
#
#  block_6_depthwise_BN (BatchNor  (None, 14, 14, 192)  768        ['block_6_depthwise[0][0]']
#  malization)
#
#  block_6_depthwise_relu (ReLU)  (None, 14, 14, 192)  0           ['block_6_depthwise_BN[0][0]']
#
#  block_6_project (Conv2D)       (None, 14, 14, 64)   12288       ['block_6_depthwise_relu[0][0]']
#
#  block_6_project_BN (BatchNorma  (None, 14, 14, 64)  256         ['block_6_project[0][0]']
#  lization)
#
#  block_7_expand (Conv2D)        (None, 14, 14, 384)  24576       ['block_6_project_BN[0][0]']
#
#  block_7_expand_BN (BatchNormal  (None, 14, 14, 384)  1536       ['block_7_expand[0][0]']
#  ization)
#
#  block_7_expand_relu (ReLU)     (None, 14, 14, 384)  0           ['block_7_expand_BN[0][0]']
#
#  block_7_depthwise (DepthwiseCo  (None, 14, 14, 384)  3456       ['block_7_expand_relu[0][0]']
#  nv2D)
#
#  block_7_depthwise_BN (BatchNor  (None, 14, 14, 384)  1536       ['block_7_depthwise[0][0]']
#  malization)
#
#  block_7_depthwise_relu (ReLU)  (None, 14, 14, 384)  0           ['block_7_depthwise_BN[0][0]']
#
#  block_7_project (Conv2D)       (None, 14, 14, 64)   24576       ['block_7_depthwise_relu[0][0]']
#
#  block_7_project_BN (BatchNorma  (None, 14, 14, 64)  256         ['block_7_project[0][0]']
#  lization)
#
#  block_7_add (Add)              (None, 14, 14, 64)   0           ['block_6_project_BN[0][0]',
#                                                                   'block_7_project_BN[0][0]']
#
#  block_8_expand (Conv2D)        (None, 14, 14, 384)  24576       ['block_7_add[0][0]']
#
#  block_8_expand_BN (BatchNormal  (None, 14, 14, 384)  1536       ['block_8_expand[0][0]']
#  ization)
#
#  block_8_expand_relu (ReLU)     (None, 14, 14, 384)  0           ['block_8_expand_BN[0][0]']
#
#  block_8_depthwise (DepthwiseCo  (None, 14, 14, 384)  3456       ['block_8_expand_relu[0][0]']
#  nv2D)
#
#  block_8_depthwise_BN (BatchNor  (None, 14, 14, 384)  1536       ['block_8_depthwise[0][0]']
#  malization)
#
#  block_8_depthwise_relu (ReLU)  (None, 14, 14, 384)  0           ['block_8_depthwise_BN[0][0]']
#
#  block_8_project (Conv2D)       (None, 14, 14, 64)   24576       ['block_8_depthwise_relu[0][0]']
#
#  block_8_project_BN (BatchNorma  (None, 14, 14, 64)  256         ['block_8_project[0][0]']
#  lization)
#
#  block_8_add (Add)              (None, 14, 14, 64)   0           ['block_7_add[0][0]',
#                                                                   'block_8_project_BN[0][0]']
#
#  block_9_expand (Conv2D)        (None, 14, 14, 384)  24576       ['block_8_add[0][0]']
#
#  block_9_expand_BN (BatchNormal  (None, 14, 14, 384)  1536       ['block_9_expand[0][0]']
#  ization)
#
#  block_9_expand_relu (ReLU)     (None, 14, 14, 384)  0           ['block_9_expand_BN[0][0]']
#
#  block_9_depthwise (DepthwiseCo  (None, 14, 14, 384)  3456       ['block_9_expand_relu[0][0]']
#  nv2D)
#
#  block_9_depthwise_BN (BatchNor  (None, 14, 14, 384)  1536       ['block_9_depthwise[0][0]']
#  malization)
#
#  block_9_depthwise_relu (ReLU)  (None, 14, 14, 384)  0           ['block_9_depthwise_BN[0][0]']
#
#  block_9_project (Conv2D)       (None, 14, 14, 64)   24576       ['block_9_depthwise_relu[0][0]']
#
#  block_9_project_BN (BatchNorma  (None, 14, 14, 64)  256         ['block_9_project[0][0]']
#  lization)
#
#  block_9_add (Add)              (None, 14, 14, 64)   0           ['block_8_add[0][0]',
#                                                                   'block_9_project_BN[0][0]']
#
#  block_10_expand (Conv2D)       (None, 14, 14, 384)  24576       ['block_9_add[0][0]']
#
#  block_10_expand_BN (BatchNorma  (None, 14, 14, 384)  1536       ['block_10_expand[0][0]']
#  lization)
#
#  block_10_expand_relu (ReLU)    (None, 14, 14, 384)  0           ['block_10_expand_BN[0][0]']
#
#  block_10_depthwise (DepthwiseC  (None, 14, 14, 384)  3456       ['block_10_expand_relu[0][0]']
#  onv2D)
#
#  block_10_depthwise_BN (BatchNo  (None, 14, 14, 384)  1536       ['block_10_depthwise[0][0]']
#  rmalization)
#
#  block_10_depthwise_relu (ReLU)  (None, 14, 14, 384)  0          ['block_10_depthwise_BN[0][0]']
#
#  block_10_project (Conv2D)      (None, 14, 14, 96)   36864       ['block_10_depthwise_relu[0][0]']
#
#  block_10_project_BN (BatchNorm  (None, 14, 14, 96)  384         ['block_10_project[0][0]']
#  alization)
#
#  block_11_expand (Conv2D)       (None, 14, 14, 576)  55296       ['block_10_project_BN[0][0]']
#
#  block_11_expand_BN (BatchNorma  (None, 14, 14, 576)  2304       ['block_11_expand[0][0]']
#  lization)
#
#  block_11_expand_relu (ReLU)    (None, 14, 14, 576)  0           ['block_11_expand_BN[0][0]']
#
#  block_11_depthwise (DepthwiseC  (None, 14, 14, 576)  5184       ['block_11_expand_relu[0][0]']
#  onv2D)
#
#  block_11_depthwise_BN (BatchNo  (None, 14, 14, 576)  2304       ['block_11_depthwise[0][0]']
#  rmalization)
#
#  block_11_depthwise_relu (ReLU)  (None, 14, 14, 576)  0          ['block_11_depthwise_BN[0][0]']
#
#  block_11_project (Conv2D)      (None, 14, 14, 96)   55296       ['block_11_depthwise_relu[0][0]']
#
#  block_11_project_BN (BatchNorm  (None, 14, 14, 96)  384         ['block_11_project[0][0]']
#  alization)
#
#  block_11_add (Add)             (None, 14, 14, 96)   0           ['block_10_project_BN[0][0]',
#                                                                   'block_11_project_BN[0][0]']
#
#  block_12_expand (Conv2D)       (None, 14, 14, 576)  55296       ['block_11_add[0][0]']
#
#  block_12_expand_BN (BatchNorma  (None, 14, 14, 576)  2304       ['block_12_expand[0][0]']
#  lization)
#
#  block_12_expand_relu (ReLU)    (None, 14, 14, 576)  0           ['block_12_expand_BN[0][0]']
#
#  block_12_depthwise (DepthwiseC  (None, 14, 14, 576)  5184       ['block_12_expand_relu[0][0]']
#  onv2D)
#
#  block_12_depthwise_BN (BatchNo  (None, 14, 14, 576)  2304       ['block_12_depthwise[0][0]']
#  rmalization)
#
#  block_12_depthwise_relu (ReLU)  (None, 14, 14, 576)  0          ['block_12_depthwise_BN[0][0]']
#
#  block_12_project (Conv2D)      (None, 14, 14, 96)   55296       ['block_12_depthwise_relu[0][0]']
#
#  block_12_project_BN (BatchNorm  (None, 14, 14, 96)  384         ['block_12_project[0][0]']
#  alization)
#
#  block_12_add (Add)             (None, 14, 14, 96)   0           ['block_11_add[0][0]',
#                                                                   'block_12_project_BN[0][0]']
#
#  block_13_expand (Conv2D)       (None, 14, 14, 576)  55296       ['block_12_add[0][0]']
#
#  block_13_expand_BN (BatchNorma  (None, 14, 14, 576)  2304       ['block_13_expand[0][0]']
#  lization)
#
#  block_13_expand_relu (ReLU)    (None, 14, 14, 576)  0           ['block_13_expand_BN[0][0]']
#
#  block_13_pad (ZeroPadding2D)   (None, 15, 15, 576)  0           ['block_13_expand_relu[0][0]']
#
#  block_13_depthwise (DepthwiseC  (None, 7, 7, 576)   5184        ['block_13_pad[0][0]']
#  onv2D)
#
#  block_13_depthwise_BN (BatchNo  (None, 7, 7, 576)   2304        ['block_13_depthwise[0][0]']
#  rmalization)
#
#  block_13_depthwise_relu (ReLU)  (None, 7, 7, 576)   0           ['block_13_depthwise_BN[0][0]']
#
#  block_13_project (Conv2D)      (None, 7, 7, 160)    92160       ['block_13_depthwise_relu[0][0]']
#
#  block_13_project_BN (BatchNorm  (None, 7, 7, 160)   640         ['block_13_project[0][0]']
#  alization)
#
#  block_14_expand (Conv2D)       (None, 7, 7, 960)    153600      ['block_13_project_BN[0][0]']
#
#  block_14_expand_BN (BatchNorma  (None, 7, 7, 960)   3840        ['block_14_expand[0][0]']
#  lization)
#
#  block_14_expand_relu (ReLU)    (None, 7, 7, 960)    0           ['block_14_expand_BN[0][0]']
#  block_14_depthwise (DepthwiseC  (None, 7, 7, 960)   8640        ['block_14_expand_relu[0][0]']
#  onv2D)
#
#  block_14_depthwise_BN (BatchNo  (None, 7, 7, 960)   3840        ['block_14_depthwise[0][0]']
#  rmalization)
#
#  block_14_depthwise_relu (ReLU)  (None, 7, 7, 960)   0           ['block_14_depthwise_BN[0][0]']
#
#  block_14_project (Conv2D)      (None, 7, 7, 160)    153600      ['block_14_depthwise_relu[0][0]']
#
#  block_14_project_BN (BatchNorm  (None, 7, 7, 160)   640         ['block_14_project[0][0]']
#  alization)
#
#  block_14_add (Add)             (None, 7, 7, 160)    0           ['block_13_project_BN[0][0]',
#                                                                   'block_14_project_BN[0][0]']
#
#  block_15_expand (Conv2D)       (None, 7, 7, 960)    153600      ['block_14_add[0][0]']
#
#  block_15_expand_BN (BatchNorma  (None, 7, 7, 960)   3840        ['block_15_expand[0][0]']
#  lization)
#
#  block_15_expand_relu (ReLU)    (None, 7, 7, 960)    0           ['block_15_expand_BN[0][0]']
#
#  block_15_depthwise (DepthwiseC  (None, 7, 7, 960)   8640        ['block_15_expand_relu[0][0]']
#  onv2D)
#
#  block_15_depthwise_BN (BatchNo  (None, 7, 7, 960)   3840        ['block_15_depthwise[0][0]']
#  rmalization)
#
#  block_15_depthwise_relu (ReLU)  (None, 7, 7, 960)   0           ['block_15_depthwise_BN[0][0]']
#
#  block_15_project (Conv2D)      (None, 7, 7, 160)    153600      ['block_15_depthwise_relu[0][0]']
#
#  block_15_project_BN (BatchNorm  (None, 7, 7, 160)   640         ['block_15_project[0][0]']
#  alization)
#
#  block_15_add (Add)             (None, 7, 7, 160)    0           ['block_14_add[0][0]',
#                                                                   'block_15_project_BN[0][0]']
#
#  block_16_expand (Conv2D)       (None, 7, 7, 960)    153600      ['block_15_add[0][0]']
#
#  block_16_expand_BN (BatchNorma  (None, 7, 7, 960)   3840        ['block_16_expand[0][0]']
#  lization)
#
#  block_16_expand_relu (ReLU)    (None, 7, 7, 960)    0           ['block_16_expand_BN[0][0]']
#
#  block_16_depthwise (DepthwiseC  (None, 7, 7, 960)   8640        ['block_16_expand_relu[0][0]']
#  onv2D)
#
#  block_16_depthwise_BN (BatchNo  (None, 7, 7, 960)   3840        ['block_16_depthwise[0][0]']
#  rmalization)
#
#  block_16_depthwise_relu (ReLU)  (None, 7, 7, 960)   0           ['block_16_depthwise_BN[0][0]']
#
#  block_16_project (Conv2D)      (None, 7, 7, 320)    307200      ['block_16_depthwise_relu[0][0]']
#
#  block_16_project_BN (BatchNorm  (None, 7, 7, 320)   1280        ['block_16_project[0][0]']
#  alization)
#
#  Conv_1 (Conv2D)                (None, 7, 7, 1280)   409600      ['block_16_project_BN[0][0]']
#
#  Conv_1_bn (BatchNormalization)  (None, 7, 7, 1280)  5120        ['Conv_1[0][0]']
#
#  out_relu (ReLU)                (None, 7, 7, 1280)   0           ['Conv_1_bn[0][0]']
#
# ==================================================================================================
# Total params: 2,257,984
# Trainable params: 2,223,872
# Non-trainable params: 34,112
# __________________________________________________________________________________________________

# %%
# load MobileNetV2 with transfer learning 
mobilenetv2_pretrained = keras.models.load_model(f"{MODEL_PATH}/MobileNetV2.h5")

# remove the fully connected layers
mobilenetv2_pretrained_fe = Model(inputs = mobilenetv2_pretrained.inputs, outputs = mobilenetv2_pretrained.layers[-4].output)
mobilenetv2_pretrained_fe.trainable = True
mobilenetv2_pretrained_fe.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  Conv1 (Conv2D)                 (None, 112, 112, 32  864         ['input_1[0][0]']
#                                 )
#
#  bn_Conv1 (BatchNormalization)  (None, 112, 112, 32  128         ['Conv1[0][0]']
#                                 )
#
#  Conv1_relu (ReLU)              (None, 112, 112, 32  0           ['bn_Conv1[0][0]']
#                                 )
#
#  expanded_conv_depthwise (Depth  (None, 112, 112, 32  288        ['Conv1_relu[0][0]']
#  wiseConv2D)                    )
#
#  expanded_conv_depthwise_BN (Ba  (None, 112, 112, 32  128        ['expanded_conv_depthwise[0][0]']
#  tchNormalization)              )
#
#  expanded_conv_depthwise_relu (  (None, 112, 112, 32  0          ['expanded_conv_depthwise_BN[0][0
#  ReLU)                          )                                ]']
#
#  expanded_conv_project (Conv2D)  (None, 112, 112, 16  512        ['expanded_conv_depthwise_relu[0]
#                                 )                                [0]']
#
#  expanded_conv_project_BN (Batc  (None, 112, 112, 16  64         ['expanded_conv_project[0][0]']
#  hNormalization)                )
#
#  block_1_expand (Conv2D)        (None, 112, 112, 96  1536        ['expanded_conv_project_BN[0][0]'
#                                 )                                ]
#
#  block_1_expand_BN (BatchNormal  (None, 112, 112, 96  384        ['block_1_expand[0][0]']
#  ization)                       )
#
#  block_1_expand_relu (ReLU)     (None, 112, 112, 96  0           ['block_1_expand_BN[0][0]']
#                                 )
#
#  block_1_pad (ZeroPadding2D)    (None, 113, 113, 96  0           ['block_1_expand_relu[0][0]']
#                                 )
#
#  block_1_depthwise (DepthwiseCo  (None, 56, 56, 96)  864         ['block_1_pad[0][0]']
#  nv2D)
#
#  block_1_depthwise_BN (BatchNor  (None, 56, 56, 96)  384         ['block_1_depthwise[0][0]']
#  malization)
#
#  block_1_depthwise_relu (ReLU)  (None, 56, 56, 96)   0           ['block_1_depthwise_BN[0][0]']
#
#  block_1_project (Conv2D)       (None, 56, 56, 24)   2304        ['block_1_depthwise_relu[0][0]']
#
#  block_1_project_BN (BatchNorma  (None, 56, 56, 24)  96          ['block_1_project[0][0]']
#  lization)
#
#  block_2_expand (Conv2D)        (None, 56, 56, 144)  3456        ['block_1_project_BN[0][0]']
#
#  block_2_expand_BN (BatchNormal  (None, 56, 56, 144)  576        ['block_2_expand[0][0]']
#  ization)
#
#  block_2_expand_relu (ReLU)     (None, 56, 56, 144)  0           ['block_2_expand_BN[0][0]']
#
#  block_2_depthwise (DepthwiseCo  (None, 56, 56, 144)  1296       ['block_2_expand_relu[0][0]']
#  nv2D)
#
#  block_2_depthwise_BN (BatchNor  (None, 56, 56, 144)  576        ['block_2_depthwise[0][0]']
#  malization)
#
#  block_2_depthwise_relu (ReLU)  (None, 56, 56, 144)  0           ['block_2_depthwise_BN[0][0]']
#
#  block_2_project (Conv2D)       (None, 56, 56, 24)   3456        ['block_2_depthwise_relu[0][0]']
#
#  block_2_project_BN (BatchNorma  (None, 56, 56, 24)  96          ['block_2_project[0][0]']
#  lization)
#
#  block_2_add (Add)              (None, 56, 56, 24)   0           ['block_1_project_BN[0][0]',
#                                                                   'block_2_project_BN[0][0]']
#
#  block_3_expand (Conv2D)        (None, 56, 56, 144)  3456        ['block_2_add[0][0]']
#
#  block_3_expand_BN (BatchNormal  (None, 56, 56, 144)  576        ['block_3_expand[0][0]']
#  ization)
#  block_3_expand_relu (ReLU)     (None, 56, 56, 144)  0           ['block_3_expand_BN[0][0]']
#
#  block_3_pad (ZeroPadding2D)    (None, 57, 57, 144)  0           ['block_3_expand_relu[0][0]']
#
#  block_3_depthwise (DepthwiseCo  (None, 28, 28, 144)  1296       ['block_3_pad[0][0]']
#  nv2D)
#
#  block_3_depthwise_BN (BatchNor  (None, 28, 28, 144)  576        ['block_3_depthwise[0][0]']
#  malization)
#
#  block_3_depthwise_relu (ReLU)  (None, 28, 28, 144)  0           ['block_3_depthwise_BN[0][0]']
#
#  block_3_project (Conv2D)       (None, 28, 28, 32)   4608        ['block_3_depthwise_relu[0][0]']
#
#  block_3_project_BN (BatchNorma  (None, 28, 28, 32)  128         ['block_3_project[0][0]']
#  lization)
#
#  block_4_expand (Conv2D)        (None, 28, 28, 192)  6144        ['block_3_project_BN[0][0]']
#
#  block_4_expand_BN (BatchNormal  (None, 28, 28, 192)  768        ['block_4_expand[0][0]']
#  ization)
#
#  block_4_expand_relu (ReLU)     (None, 28, 28, 192)  0           ['block_4_expand_BN[0][0]']
#
#  block_4_depthwise (DepthwiseCo  (None, 28, 28, 192)  1728       ['block_4_expand_relu[0][0]']
#  nv2D)
#
#  block_4_depthwise_BN (BatchNor  (None, 28, 28, 192)  768        ['block_4_depthwise[0][0]']
#  malization)
#
#  block_4_depthwise_relu (ReLU)  (None, 28, 28, 192)  0           ['block_4_depthwise_BN[0][0]']
#
#  block_4_project (Conv2D)       (None, 28, 28, 32)   6144        ['block_4_depthwise_relu[0][0]']
#
#  block_4_project_BN (BatchNorma  (None, 28, 28, 32)  128         ['block_4_project[0][0]']
#  lization)
#
#  block_4_add (Add)              (None, 28, 28, 32)   0           ['block_3_project_BN[0][0]',
#                                                                   'block_4_project_BN[0][0]']
#
#  block_5_expand (Conv2D)        (None, 28, 28, 192)  6144        ['block_4_add[0][0]']
#
#  block_5_expand_BN (BatchNormal  (None, 28, 28, 192)  768        ['block_5_expand[0][0]']
#  ization)
#
#  block_5_expand_relu (ReLU)     (None, 28, 28, 192)  0           ['block_5_expand_BN[0][0]']
#
#  block_5_depthwise (DepthwiseCo  (None, 28, 28, 192)  1728       ['block_5_expand_relu[0][0]']
#  nv2D)
#
#  block_5_depthwise_BN (BatchNor  (None, 28, 28, 192)  768        ['block_5_depthwise[0][0]']
#  malization)
#
#  block_5_depthwise_relu (ReLU)  (None, 28, 28, 192)  0           ['block_5_depthwise_BN[0][0]']
#
#  block_5_project (Conv2D)       (None, 28, 28, 32)   6144        ['block_5_depthwise_relu[0][0]']
#
#  block_5_project_BN (BatchNorma  (None, 28, 28, 32)  128         ['block_5_project[0][0]']
#  lization)
#
#  block_5_add (Add)              (None, 28, 28, 32)   0           ['block_4_add[0][0]',
#                                                                   'block_5_project_BN[0][0]']
#
#  block_6_expand (Conv2D)        (None, 28, 28, 192)  6144        ['block_5_add[0][0]']
#
#  block_6_expand_BN (BatchNormal  (None, 28, 28, 192)  768        ['block_6_expand[0][0]']
#  ization)
#
#  block_6_expand_relu (ReLU)     (None, 28, 28, 192)  0           ['block_6_expand_BN[0][0]']
#
#  block_6_pad (ZeroPadding2D)    (None, 29, 29, 192)  0           ['block_6_expand_relu[0][0]']
#
#  block_6_depthwise (DepthwiseCo  (None, 14, 14, 192)  1728       ['block_6_pad[0][0]']
#  nv2D)
#
#  block_6_depthwise_BN (BatchNor  (None, 14, 14, 192)  768        ['block_6_depthwise[0][0]']
#  malization)
#
#  block_6_depthwise_relu (ReLU)  (None, 14, 14, 192)  0           ['block_6_depthwise_BN[0][0]']
#
#  block_6_project (Conv2D)       (None, 14, 14, 64)   12288       ['block_6_depthwise_relu[0][0]']
#
#  block_6_project_BN (BatchNorma  (None, 14, 14, 64)  256         ['block_6_project[0][0]']
#  lization)
#
#  block_7_expand (Conv2D)        (None, 14, 14, 384)  24576       ['block_6_project_BN[0][0]']
#
#  block_7_expand_BN (BatchNormal  (None, 14, 14, 384)  1536       ['block_7_expand[0][0]']
#  ization)
#
#  block_7_expand_relu (ReLU)     (None, 14, 14, 384)  0           ['block_7_expand_BN[0][0]']
#
#  block_7_depthwise (DepthwiseCo  (None, 14, 14, 384)  3456       ['block_7_expand_relu[0][0]']
#  nv2D)
#
#  block_7_depthwise_BN (BatchNor  (None, 14, 14, 384)  1536       ['block_7_depthwise[0][0]']
#  malization)
#
#  block_7_depthwise_relu (ReLU)  (None, 14, 14, 384)  0           ['block_7_depthwise_BN[0][0]']
#
#  block_7_project (Conv2D)       (None, 14, 14, 64)   24576       ['block_7_depthwise_relu[0][0]']
#
#  block_7_project_BN (BatchNorma  (None, 14, 14, 64)  256         ['block_7_project[0][0]']
#  lization)
#
#  block_7_add (Add)              (None, 14, 14, 64)   0           ['block_6_project_BN[0][0]',
#                                                                   'block_7_project_BN[0][0]']
#
#  block_8_expand (Conv2D)        (None, 14, 14, 384)  24576       ['block_7_add[0][0]']
#
#  block_8_expand_BN (BatchNormal  (None, 14, 14, 384)  1536       ['block_8_expand[0][0]']
#  ization)
#
#  block_8_expand_relu (ReLU)     (None, 14, 14, 384)  0           ['block_8_expand_BN[0][0]']
#
#  block_8_depthwise (DepthwiseCo  (None, 14, 14, 384)  3456       ['block_8_expand_relu[0][0]']
#  nv2D)
#
#  block_8_depthwise_BN (BatchNor  (None, 14, 14, 384)  1536       ['block_8_depthwise[0][0]']
#  malization)
#
#  block_8_depthwise_relu (ReLU)  (None, 14, 14, 384)  0           ['block_8_depthwise_BN[0][0]']
#
#  block_8_project (Conv2D)       (None, 14, 14, 64)   24576       ['block_8_depthwise_relu[0][0]']
#
#  block_8_project_BN (BatchNorma  (None, 14, 14, 64)  256         ['block_8_project[0][0]']
#  lization)
#
#  block_8_add (Add)              (None, 14, 14, 64)   0           ['block_7_add[0][0]',
#                                                                   'block_8_project_BN[0][0]']
#
#  block_9_expand (Conv2D)        (None, 14, 14, 384)  24576       ['block_8_add[0][0]']
#
#  block_9_expand_BN (BatchNormal  (None, 14, 14, 384)  1536       ['block_9_expand[0][0]']
#  ization)
#
#  block_9_expand_relu (ReLU)     (None, 14, 14, 384)  0           ['block_9_expand_BN[0][0]']
#
#  block_9_depthwise (DepthwiseCo  (None, 14, 14, 384)  3456       ['block_9_expand_relu[0][0]']
#  nv2D)
#
#  block_9_depthwise_BN (BatchNor  (None, 14, 14, 384)  1536       ['block_9_depthwise[0][0]']
#  malization)
#
#  block_9_depthwise_relu (ReLU)  (None, 14, 14, 384)  0           ['block_9_depthwise_BN[0][0]']
#
#  block_9_project (Conv2D)       (None, 14, 14, 64)   24576       ['block_9_depthwise_relu[0][0]']
#
#  block_9_project_BN (BatchNorma  (None, 14, 14, 64)  256         ['block_9_project[0][0]']
#  lization)
#
#  block_9_add (Add)              (None, 14, 14, 64)   0           ['block_8_add[0][0]',
#                                                                   'block_9_project_BN[0][0]']
#
#  block_10_expand (Conv2D)       (None, 14, 14, 384)  24576       ['block_9_add[0][0]']
#
#  block_10_expand_BN (BatchNorma  (None, 14, 14, 384)  1536       ['block_10_expand[0][0]']
#  lization)
#
#  block_10_expand_relu (ReLU)    (None, 14, 14, 384)  0           ['block_10_expand_BN[0][0]']
#
#  block_10_depthwise (DepthwiseC  (None, 14, 14, 384)  3456       ['block_10_expand_relu[0][0]']
#  onv2D)
#
#  block_10_depthwise_BN (BatchNo  (None, 14, 14, 384)  1536       ['block_10_depthwise[0][0]']
#  rmalization)
#
#  block_10_depthwise_relu (ReLU)  (None, 14, 14, 384)  0          ['block_10_depthwise_BN[0][0]']
#
#  block_10_project (Conv2D)      (None, 14, 14, 96)   36864       ['block_10_depthwise_relu[0][0]']
#
#  block_10_project_BN (BatchNorm  (None, 14, 14, 96)  384         ['block_10_project[0][0]']
#  alization)
#
#  block_11_expand (Conv2D)       (None, 14, 14, 576)  55296       ['block_10_project_BN[0][0]']
#
#  block_11_expand_BN (BatchNorma  (None, 14, 14, 576)  2304       ['block_11_expand[0][0]']
#  lization)
#
#  block_11_expand_relu (ReLU)    (None, 14, 14, 576)  0           ['block_11_expand_BN[0][0]']
#
#  block_11_depthwise (DepthwiseC  (None, 14, 14, 576)  5184       ['block_11_expand_relu[0][0]']
#  onv2D)
#
#  block_11_depthwise_BN (BatchNo  (None, 14, 14, 576)  2304       ['block_11_depthwise[0][0]']
#  rmalization)
#
#  block_11_depthwise_relu (ReLU)  (None, 14, 14, 576)  0          ['block_11_depthwise_BN[0][0]']
#
#  block_11_project (Conv2D)      (None, 14, 14, 96)   55296       ['block_11_depthwise_relu[0][0]']
#
#  block_11_project_BN (BatchNorm  (None, 14, 14, 96)  384         ['block_11_project[0][0]']
#  alization)
#
#  block_11_add (Add)             (None, 14, 14, 96)   0           ['block_10_project_BN[0][0]',
#                                                                   'block_11_project_BN[0][0]']
#
#  block_12_expand (Conv2D)       (None, 14, 14, 576)  55296       ['block_11_add[0][0]']
#
#  block_12_expand_BN (BatchNorma  (None, 14, 14, 576)  2304       ['block_12_expand[0][0]']
#  lization)
#
#  block_12_expand_relu (ReLU)    (None, 14, 14, 576)  0           ['block_12_expand_BN[0][0]']
#
#  block_12_depthwise (DepthwiseC  (None, 14, 14, 576)  5184       ['block_12_expand_relu[0][0]']
#  onv2D)
#
#  block_12_depthwise_BN (BatchNo  (None, 14, 14, 576)  2304       ['block_12_depthwise[0][0]']
#  rmalization)
#
#  block_12_depthwise_relu (ReLU)  (None, 14, 14, 576)  0          ['block_12_depthwise_BN[0][0]']
#
#  block_12_project (Conv2D)      (None, 14, 14, 96)   55296       ['block_12_depthwise_relu[0][0]']
#
#  block_12_project_BN (BatchNorm  (None, 14, 14, 96)  384         ['block_12_project[0][0]']
#  alization)
#
#  block_12_add (Add)             (None, 14, 14, 96)   0           ['block_11_add[0][0]',
#                                                                   'block_12_project_BN[0][0]']
#
#  block_13_expand (Conv2D)       (None, 14, 14, 576)  55296       ['block_12_add[0][0]']
#
#  block_13_expand_BN (BatchNorma  (None, 14, 14, 576)  2304       ['block_13_expand[0][0]']
#  lization)
#
#  block_13_expand_relu (ReLU)    (None, 14, 14, 576)  0           ['block_13_expand_BN[0][0]']
#
#  block_13_pad (ZeroPadding2D)   (None, 15, 15, 576)  0           ['block_13_expand_relu[0][0]']
#
#  block_13_depthwise (DepthwiseC  (None, 7, 7, 576)   5184        ['block_13_pad[0][0]']
#  onv2D)
#
#  block_13_depthwise_BN (BatchNo  (None, 7, 7, 576)   2304        ['block_13_depthwise[0][0]']
#  rmalization)
#
#  block_13_depthwise_relu (ReLU)  (None, 7, 7, 576)   0           ['block_13_depthwise_BN[0][0]']
#
#  block_13_project (Conv2D)      (None, 7, 7, 160)    92160       ['block_13_depthwise_relu[0][0]']
#
#  block_13_project_BN (BatchNorm  (None, 7, 7, 160)   640         ['block_13_project[0][0]']
#  alization)
#
#  block_14_expand (Conv2D)       (None, 7, 7, 960)    153600      ['block_13_project_BN[0][0]']
#
#  block_14_expand_BN (BatchNorma  (None, 7, 7, 960)   3840        ['block_14_expand[0][0]']
#  lization)
#
#  block_14_expand_relu (ReLU)    (None, 7, 7, 960)    0           ['block_14_expand_BN[0][0]']
#  block_14_depthwise (DepthwiseC  (None, 7, 7, 960)   8640        ['block_14_expand_relu[0][0]']
#  onv2D)
#
#  block_14_depthwise_BN (BatchNo  (None, 7, 7, 960)   3840        ['block_14_depthwise[0][0]']
#  rmalization)
#
#  block_14_depthwise_relu (ReLU)  (None, 7, 7, 960)   0           ['block_14_depthwise_BN[0][0]']
#
#  block_14_project (Conv2D)      (None, 7, 7, 160)    153600      ['block_14_depthwise_relu[0][0]']
#
#  block_14_project_BN (BatchNorm  (None, 7, 7, 160)   640         ['block_14_project[0][0]']
#  alization)
#
#  block_14_add (Add)             (None, 7, 7, 160)    0           ['block_13_project_BN[0][0]',
#                                                                   'block_14_project_BN[0][0]']
#
#  block_15_expand (Conv2D)       (None, 7, 7, 960)    153600      ['block_14_add[0][0]']
#
#  block_15_expand_BN (BatchNorma  (None, 7, 7, 960)   3840        ['block_15_expand[0][0]']
#  lization)
#
#  block_15_expand_relu (ReLU)    (None, 7, 7, 960)    0           ['block_15_expand_BN[0][0]']
#
#  block_15_depthwise (DepthwiseC  (None, 7, 7, 960)   8640        ['block_15_expand_relu[0][0]']
#  onv2D)
#
#  block_15_depthwise_BN (BatchNo  (None, 7, 7, 960)   3840        ['block_15_depthwise[0][0]']
#  rmalization)
#
#  block_15_depthwise_relu (ReLU)  (None, 7, 7, 960)   0           ['block_15_depthwise_BN[0][0]']
#
#  block_15_project (Conv2D)      (None, 7, 7, 160)    153600      ['block_15_depthwise_relu[0][0]']
#
#  block_15_project_BN (BatchNorm  (None, 7, 7, 160)   640         ['block_15_project[0][0]']
#  alization)
#
#  block_15_add (Add)             (None, 7, 7, 160)    0           ['block_14_add[0][0]',
#                                                                   'block_15_project_BN[0][0]']
#
#  block_16_expand (Conv2D)       (None, 7, 7, 960)    153600      ['block_15_add[0][0]']
#
#  block_16_expand_BN (BatchNorma  (None, 7, 7, 960)   3840        ['block_16_expand[0][0]']
#  lization)
#
#  block_16_expand_relu (ReLU)    (None, 7, 7, 960)    0           ['block_16_expand_BN[0][0]']
#
#  block_16_depthwise (DepthwiseC  (None, 7, 7, 960)   8640        ['block_16_expand_relu[0][0]']
#  onv2D)
#
#  block_16_depthwise_BN (BatchNo  (None, 7, 7, 960)   3840        ['block_16_depthwise[0][0]']
#  rmalization)
#
#  block_16_depthwise_relu (ReLU)  (None, 7, 7, 960)   0           ['block_16_depthwise_BN[0][0]']
#
#  block_16_project (Conv2D)      (None, 7, 7, 320)    307200      ['block_16_depthwise_relu[0][0]']
#
#  block_16_project_BN (BatchNorm  (None, 7, 7, 320)   1280        ['block_16_project[0][0]']
#  alization)
#
#  Conv_1 (Conv2D)                (None, 7, 7, 1280)   409600      ['block_16_project_BN[0][0]']
#
#  Conv_1_bn (BatchNormalization)  (None, 7, 7, 1280)  5120        ['Conv_1[0][0]']
#
#  out_relu (ReLU)                (None, 7, 7, 1280)   0           ['Conv_1_bn[0][0]']
#
#  dense_2 (Dense)                (None, 7, 7, 6)      7686        ['out_relu[0][0]']
#
# ==================================================================================================
# Total params: 2,265,670
# Trainable params: 2,231,558
# Non-trainable params: 34,112
# __________________________________________________________________________________________________

# %%
# extracting features with pretrained weights
model_name = "Cassava_Dataset_MobileNetv2_pretrained"
extractFeatures(mobilenetv2_pretrained_fe, output_shape = 7 * 7 * 6, model_name = model_name)
# Out:
# [INFO] processing train split...
# [INFO] processing batch 1/469
# 1/1 [==============================] - 1s 1s/step
# [INFO] processing batch 2/469
# 1/1 [==============================] - 0s 423ms/step
# [INFO] processing batch 3/469
# 1/1 [==============================] - 0s 439ms/step
# [INFO] processing batch 4/469
# 1/1 [==============================] - 0s 455ms/step
# [INFO] processing batch 5/469
# 1/1 [==============================] - 0s 440ms/step
# [INFO] processing batch 6/469
# 1/1 [==============================] - 0s 419ms/step
# [INFO] processing batch 7/469
# 1/1 [==============================] - 0s 394ms/step
# [INFO] processing batch 8/469
# 1/1 [==============================] - 0s 403ms/step
# [INFO] processing batch 9/469
# 1/1 [==============================] - 0s 396ms/step
# [INFO] processing batch 10/469
# 1/1 [==============================] - 0s 400ms/step
# [INFO] processing batch 11/469
# 1/1 [==============================] - 0s 422ms/step
# [INFO] processing batch 12/469
# 1/1 [==============================] - 0s 399ms/step
# [INFO] processing batch 13/469
# 1/1 [==============================] - 0s 419ms/step
# [INFO] processing batch 14/469
# 1/1 [==============================] - 0s 422ms/step
# [INFO] processing batch 15/469
# 1/1 [==============================] - 0s 406ms/step
# [INFO] processing batch 16/469
# 1/1 [==============================] - 0s 407ms/step
# [INFO] processing batch 17/469
# 1/1 [==============================] - 0s 425ms/step
# [INFO] processing batch 18/469
# 1/1 [==============================] - 0s 410ms/step
# [INFO] processing batch 19/469
# 1/1 [==============================] - 0s 411ms/step
# [INFO] processing batch 20/469
# 1/1 [==============================] - 0s 393ms/step
# [INFO] processing batch 21/469
# 1/1 [==============================] - 0s 399ms/step
# [INFO] processing batch 22/469
# 1/1 [==============================] - 0s 395ms/step
# [INFO] processing batch 23/469
# 1/1 [==============================] - 0s 392ms/step
# [INFO] processing batch 24/469
# 1/1 [==============================] - 0s 401ms/step
# [INFO] processing batch 25/469
# 1/1 [==============================] - 0s 397ms/step
# [INFO] processing batch 26/469
# 1/1 [==============================] - 0s 400ms/step
# [INFO] processing batch 27/469
# 1/1 [==============================] - 0s 407ms/step
# [INFO] processing batch 28/469
# 1/1 [==============================] - 0s 403ms/step
# [INFO] processing batch 29/469
# 1/1 [==============================] - 0s 408ms/step
# [INFO] processing batch 30/469
# 1/1 [==============================] - 0s 392ms/step
# [INFO] processing batch 31/469
# 1/1 [==============================] - 0s 407ms/step
# [INFO] processing batch 32/469
# 1/1 [==============================] - 0s 401ms/step
# [INFO] processing batch 33/469
# 1/1 [==============================] - 0s 398ms/step
# [INFO] processing batch 34/469
# 1/1 [==============================] - 0s 408ms/step
# [INFO] processing batch 35/469
# 1/1 [==============================] - 0s 392ms/step
# [INFO] processing batch 36/469
# 1/1 [==============================] - 0s 404ms/step
# [INFO] processing batch 37/469
# 1/1 [==============================] - 0s 447ms/step
# [INFO] processing batch 38/469
# 1/1 [==============================] - 0s 423ms/step
# [INFO] processing batch 39/469
# 1/1 [==============================] - 0s 399ms/step
# [INFO] processing batch 40/469
# 1/1 [==============================] - 0s 399ms/step
# [INFO] processing batch 41/469
# 1/1 [==============================] - 0s 399ms/step
# [INFO] processing batch 42/469
# 1/1 [==============================] - 0s 397ms/step
# [INFO] processing batch 43/469
# 1/1 [==============================] - 0s 398ms/step
# [INFO] processing batch 44/469
# 1/1 [==============================] - 0s 407ms/step
# [INFO] processing batch 45/469
# 1/1 [==============================] - 0s 399ms/step
# [INFO] processing batch 46/469
# 1/1 [==============================] - 0s 392ms/step
# [INFO] processing batch 47/469
# 1/1 [==============================] - 0s 408ms/step
# [INFO] processing batch 48/469
# 1/1 [==============================] - 0s 398ms/step
# [INFO] processing batch 49/469
# 1/1 [==============================] - 0s 394ms/step
# [INFO] processing batch 50/469
# 1/1 [==============================] - 0s 392ms/step
# [INFO] processing batch 51/469
# 1/1 [==============================] - 0s 406ms/step
# [INFO] processing batch 52/469
# 1/1 [==============================] - 0s 405ms/step
# [INFO] processing batch 53/469
# 1/1 [==============================] - 0s 395ms/step
# [INFO] processing batch 54/469
# 1/1 [==============================] - 0s 400ms/step
# [INFO] processing batch 55/469
# 1/1 [==============================] - 0s 397ms/step
# [INFO] processing batch 56/469
# 1/1 [==============================] - 0s 399ms/step
# [INFO] processing batch 57/469
# 1/1 [==============================] - 0s 396ms/step
# [INFO] processing batch 58/469
# 1/1 [==============================] - 0s 413ms/step
# [INFO] processing batch 59/469
# 1/1 [==============================] - 0s 399ms/step
# [INFO] processing batch 60/469
# 1/1 [==============================] - 0s 404ms/step
# [INFO] processing batch 61/469
# 1/1 [==============================] - 0s 392ms/step
# [INFO] processing batch 62/469
# 1/1 [==============================] - 0s 397ms/step
# [INFO] processing batch 63/469
# 1/1 [==============================] - 0s 397ms/step
# [INFO] processing batch 64/469
# 1/1 [==============================] - 0s 412ms/step
# [INFO] processing batch 65/469
# 1/1 [==============================] - 0s 390ms/step
# [INFO] processing batch 66/469
# 1/1 [==============================] - 0s 391ms/step
# [INFO] processing batch 67/469
# 1/1 [==============================] - 0s 393ms/step
# [INFO] processing batch 68/469
# 1/1 [==============================] - 0s 400ms/step
# [INFO] processing batch 69/469
# 1/1 [==============================] - 0s 405ms/step
# [INFO] processing batch 70/469
# 1/1 [==============================] - 0s 392ms/step
# [INFO] processing batch 71/469
# 1/1 [==============================] - 0s 399ms/step
# [INFO] processing batch 72/469
# 1/1 [==============================] - 0s 407ms/step
# [INFO] processing batch 73/469
# 1/1 [==============================] - 0s 391ms/step
# [INFO] processing batch 74/469
# 1/1 [==============================] - 0s 398ms/step
# [INFO] processing batch 75/469
# 1/1 [==============================] - 0s 400ms/step
# [INFO] processing batch 76/469
# 1/1 [==============================] - 0s 395ms/step
# [INFO] processing batch 77/469
# 1/1 [==============================] - 0s 391ms/step
# [INFO] processing batch 78/469
# 1/1 [==============================] - 0s 399ms/step
# [INFO] processing batch 79/469
# 1/1 [==============================] - 0s 403ms/step
# [INFO] processing batch 80/469
# 1/1 [==============================] - 0s 394ms/step
# [INFO] processing batch 81/469
# 1/1 [==============================] - 0s 396ms/step
# [INFO] processing batch 82/469
# 1/1 [==============================] - 0s 400ms/step
# [INFO] processing batch 83/469
# 1/1 [==============================] - 0s 401ms/step
# [INFO] processing batch 84/469
# 1/1 [==============================] - 0s 394ms/step
# [INFO] processing batch 85/469
# 1/1 [==============================] - 0s 391ms/step
# [INFO] processing batch 86/469
# 1/1 [==============================] - 0s 412ms/step
# [INFO] processing batch 87/469
# 1/1 [==============================] - 0s 402ms/step
# [INFO] processing batch 88/469
# 1/1 [==============================] - 0s 395ms/step
# [INFO] processing batch 89/469
# 1/1 [==============================] - 0s 397ms/step
# [INFO] processing batch 90/469
# 1/1 [==============================] - 0s 410ms/step
# [INFO] processing batch 91/469
# 1/1 [==============================] - 0s 394ms/step
# [INFO] processing batch 92/469
# 1/1 [==============================] - 0s 392ms/step
# [INFO] processing batch 93/469
# 1/1 [==============================] - 0s 400ms/step
# [INFO] processing batch 94/469
# 1/1 [==============================] - 0s 395ms/step
# [INFO] processing batch 95/469
# 1/1 [==============================] - 0s 397ms/step
# [INFO] processing batch 96/469
# 1/1 [==============================] - 0s 394ms/step
# [INFO] processing batch 97/469
# 1/1 [==============================] - 0s 398ms/step
# [INFO] processing batch 98/469
# 1/1 [==============================] - 0s 407ms/step
# [INFO] processing batch 99/469
# 1/1 [==============================] - 0s 402ms/step
# [INFO] processing batch 100/469
# 1/1 [==============================] - 0s 407ms/step
# [INFO] processing batch 101/469
# 1/1 [==============================] - 0s 393ms/step
# [INFO] processing batch 102/469
# 1/1 [==============================] - 0s 393ms/step
# [INFO] processing batch 103/469
# 1/1 [==============================] - 0s 412ms/step
# [INFO] processing batch 104/469
# 1/1 [==============================] - 0s 422ms/step
# [INFO] processing batch 105/469
# 1/1 [==============================] - 0s 395ms/step
# [INFO] processing batch 106/469
# 1/1 [==============================] - 0s 393ms/step
# [INFO] processing batch 107/469
# 1/1 [==============================] - 0s 389ms/step
# [INFO] processing batch 108/469
# 1/1 [==============================] - 0s 396ms/step
# [INFO] processing batch 109/469
# 1/1 [==============================] - 0s 396ms/step
# [INFO] processing batch 110/469
# 1/1 [==============================] - 0s 395ms/step
# [INFO] processing batch 111/469
# 1/1 [==============================] - 0s 411ms/step
# [INFO] processing batch 112/469
# 1/1 [==============================] - 0s 384ms/step
# [INFO] processing batch 113/469
# 1/1 [==============================] - 0s 403ms/step
# [INFO] processing batch 114/469
# 1/1 [==============================] - 0s 399ms/step
# [INFO] processing batch 115/469
# 1/1 [==============================] - 0s 393ms/step
# [INFO] processing batch 116/469
# 1/1 [==============================] - 0s 389ms/step
# [INFO] processing batch 117/469
# 1/1 [==============================] - 0s 398ms/step
# [INFO] processing batch 118/469
# 1/1 [==============================] - 0s 393ms/step
# [INFO] processing batch 119/469
# 1/1 [==============================] - 0s 397ms/step
# [INFO] processing batch 120/469
# 1/1 [==============================] - 0s 392ms/step
# [INFO] processing batch 121/469
# 1/1 [==============================] - 0s 398ms/step
# [INFO] processing batch 122/469
# 1/1 [==============================] - 0s 401ms/step
# [INFO] processing batch 123/469
# 1/1 [==============================] - 0s 395ms/step
# [INFO] processing batch 124/469
# 1/1 [==============================] - 0s 398ms/step
# [INFO] processing batch 125/469
# 1/1 [==============================] - 0s 394ms/step
# [INFO] processing batch 126/469
# 1/1 [==============================] - 0s 401ms/step
# [INFO] processing batch 127/469
# 1/1 [==============================] - 0s 391ms/step
# [INFO] processing batch 128/469
# 1/1 [==============================] - 0s 400ms/step
# [INFO] processing batch 129/469
# 1/1 [==============================] - 0s 389ms/step
# [INFO] processing batch 130/469
# 1/1 [==============================] - 0s 400ms/step
# [INFO] processing batch 131/469
# 1/1 [==============================] - 0s 391ms/step
# [INFO] processing batch 132/469
# 1/1 [==============================] - 0s 399ms/step
# [INFO] processing batch 133/469
# 1/1 [==============================] - 0s 393ms/step
# [INFO] processing batch 134/469
# 1/1 [==============================] - 0s 401ms/step
# [INFO] processing batch 135/469
# 1/1 [==============================] - 0s 392ms/step
# [INFO] processing batch 136/469
# 1/1 [==============================] - 0s 391ms/step
# [INFO] processing batch 137/469
# 1/1 [==============================] - 0s 394ms/step
# [INFO] processing batch 138/469
# 1/1 [==============================] - 0s 388ms/step
# [INFO] processing batch 139/469
# 1/1 [==============================] - 0s 402ms/step
# [INFO] processing batch 140/469
# 1/1 [==============================] - 0s 386ms/step
# [INFO] processing batch 141/469
# 1/1 [==============================] - 0s 446ms/step
# [INFO] processing batch 142/469
# 1/1 [==============================] - 0s 436ms/step
# [INFO] processing batch 143/469
# 1/1 [==============================] - 0s 426ms/step
# [INFO] processing batch 144/469
# 1/1 [==============================] - 0s 389ms/step
# [INFO] processing batch 145/469
# 1/1 [==============================] - 0s 406ms/step
# [INFO] processing batch 146/469
# 1/1 [==============================] - 0s 430ms/step
# [INFO] processing batch 147/469
# 1/1 [==============================] - 0s 422ms/step
# [INFO] processing batch 148/469
# 1/1 [==============================] - 0s 465ms/step
# [INFO] processing batch 149/469
# 1/1 [==============================] - 0s 410ms/step
# [INFO] processing batch 150/469
# 1/1 [==============================] - 0s 407ms/step
# [INFO] processing batch 151/469
# 1/1 [==============================] - 0s 465ms/step
# [INFO] processing batch 152/469
# 1/1 [==============================] - 0s 440ms/step
# [INFO] processing batch 153/469
# 1/1 [==============================] - 0s 411ms/step
# [INFO] processing batch 154/469
# 1/1 [==============================] - 0s 425ms/step
# [INFO] processing batch 155/469
# 1/1 [==============================] - 0s 408ms/step
# [INFO] processing batch 156/469
# 1/1 [==============================] - 0s 417ms/step
# [INFO] processing batch 157/469
# 1/1 [==============================] - 0s 437ms/step
# [INFO] processing batch 158/469
# 1/1 [==============================] - 0s 406ms/step
# [INFO] processing batch 159/469
# 1/1 [==============================] - 0s 396ms/step
# [INFO] processing batch 160/469
# 1/1 [==============================] - 0s 435ms/step
# [INFO] processing batch 161/469
# 1/1 [==============================] - 0s 435ms/step
# [INFO] processing batch 162/469
# 1/1 [==============================] - 0s 457ms/step
# [INFO] processing batch 163/469
# 1/1 [==============================] - 0s 401ms/step
# [INFO] processing batch 164/469
# 1/1 [==============================] - 0s 398ms/step
# [INFO] processing batch 165/469
# 1/1 [==============================] - 0s 410ms/step
# [INFO] processing batch 166/469
# 1/1 [==============================] - 0s 398ms/step
# [INFO] processing batch 167/469
# 1/1 [==============================] - 0s 492ms/step
# [INFO] processing batch 168/469
# 1/1 [==============================] - 0s 419ms/step
# [INFO] processing batch 169/469
# 1/1 [==============================] - 0s 404ms/step
# [INFO] processing batch 170/469
# 1/1 [==============================] - 0s 396ms/step
# [INFO] processing batch 171/469
# 1/1 [==============================] - 0s 394ms/step
# [INFO] processing batch 172/469
# 1/1 [==============================] - 0s 411ms/step
# [INFO] processing batch 173/469
# 1/1 [==============================] - 0s 397ms/step
# [INFO] processing batch 174/469
# 1/1 [==============================] - 0s 388ms/step
# [INFO] processing batch 175/469
# 1/1 [==============================] - 0s 396ms/step
# [INFO] processing batch 176/469
# 1/1 [==============================] - 0s 389ms/step
# [INFO] processing batch 177/469
# 1/1 [==============================] - 0s 396ms/step
# [INFO] processing batch 178/469
# 1/1 [==============================] - 0s 388ms/step
# [INFO] processing batch 179/469
# 1/1 [==============================] - 0s 399ms/step
# [INFO] processing batch 180/469
# 1/1 [==============================] - 0s 399ms/step
# [INFO] processing batch 181/469
# 1/1 [==============================] - 0s 397ms/step
# [INFO] processing batch 182/469
# 1/1 [==============================] - 0s 402ms/step
# [INFO] processing batch 183/469
# 1/1 [==============================] - 0s 404ms/step
# [INFO] processing batch 184/469
# 1/1 [==============================] - 0s 390ms/step
# [INFO] processing batch 185/469
# 1/1 [==============================] - 0s 390ms/step
# [INFO] processing batch 186/469
# 1/1 [==============================] - 0s 398ms/step
# [INFO] processing batch 187/469
# 1/1 [==============================] - 0s 394ms/step
# [INFO] processing batch 188/469
# 1/1 [==============================] - 0s 395ms/step
# [INFO] processing batch 189/469
# 1/1 [==============================] - 0s 389ms/step
# [INFO] processing batch 190/469
# 1/1 [==============================] - 0s 395ms/step
# [INFO] processing batch 191/469
# 1/1 [==============================] - 0s 393ms/step
# [INFO] processing batch 192/469
# 1/1 [==============================] - 0s 401ms/step
# [INFO] processing batch 193/469
# 1/1 [==============================] - 0s 399ms/step
# [INFO] processing batch 194/469
# 1/1 [==============================] - 0s 397ms/step
# [INFO] processing batch 195/469
# 1/1 [==============================] - 0s 398ms/step
# [INFO] processing batch 196/469
# 1/1 [==============================] - 0s 392ms/step
# [INFO] processing batch 197/469
# 1/1 [==============================] - 0s 393ms/step
# [INFO] processing batch 198/469
# 1/1 [==============================] - 0s 393ms/step
# [INFO] processing batch 199/469
# 1/1 [==============================] - 0s 393ms/step
# [INFO] processing batch 200/469
# 1/1 [==============================] - 0s 395ms/step
# [INFO] processing batch 201/469
# 1/1 [==============================] - 0s 399ms/step
# [INFO] processing batch 202/469
# 1/1 [==============================] - 0s 391ms/step
# [INFO] processing batch 203/469
# 1/1 [==============================] - 0s 397ms/step
# [INFO] processing batch 204/469
# 1/1 [==============================] - 0s 399ms/step
# [INFO] processing batch 205/469
# 1/1 [==============================] - 0s 397ms/step
# [INFO] processing batch 206/469
# 1/1 [==============================] - 0s 385ms/step
# [INFO] processing batch 207/469
# 1/1 [==============================] - 0s 396ms/step
# [INFO] processing batch 208/469
# 1/1 [==============================] - 0s 396ms/step
# [INFO] processing batch 209/469
# 1/1 [==============================] - 0s 402ms/step
# [INFO] processing batch 210/469
# 1/1 [==============================] - 0s 396ms/step
# [INFO] processing batch 211/469
# 1/1 [==============================] - 0s 393ms/step
# [INFO] processing batch 212/469
# 1/1 [==============================] - 0s 391ms/step
# [INFO] processing batch 213/469
# 1/1 [==============================] - 0s 396ms/step
# [INFO] processing batch 214/469
# 1/1 [==============================] - 0s 390ms/step
# [INFO] processing batch 215/469
# 1/1 [==============================] - 0s 409ms/step
# [INFO] processing batch 216/469
# 1/1 [==============================] - 0s 393ms/step
# [INFO] processing batch 217/469
# 1/1 [==============================] - 0s 386ms/step
# [INFO] processing batch 218/469
# 1/1 [==============================] - 0s 393ms/step
# [INFO] processing batch 219/469
# 1/1 [==============================] - 0s 389ms/step
# [INFO] processing batch 220/469
# 1/1 [==============================] - 0s 395ms/step
# [INFO] processing batch 221/469
# 1/1 [==============================] - 0s 400ms/step
# [INFO] processing batch 222/469
# 1/1 [==============================] - 0s 393ms/step
# [INFO] processing batch 223/469
# 1/1 [==============================] - 0s 397ms/step
# [INFO] processing batch 224/469
# 1/1 [==============================] - 0s 395ms/step
# [INFO] processing batch 225/469
# 1/1 [==============================] - 0s 394ms/step
# [INFO] processing batch 226/469
# 1/1 [==============================] - 0s 402ms/step
# [INFO] processing batch 227/469
# 1/1 [==============================] - 0s 397ms/step
# [INFO] processing batch 228/469
# 1/1 [==============================] - 0s 390ms/step
# [INFO] processing batch 229/469
# 1/1 [==============================] - 0s 393ms/step
# [INFO] processing batch 230/469
# 1/1 [==============================] - 0s 392ms/step
# [INFO] processing batch 231/469
# 1/1 [==============================] - 0s 394ms/step
# [INFO] processing batch 232/469
# 1/1 [==============================] - 0s 390ms/step
# [INFO] processing batch 233/469
# 1/1 [==============================] - 0s 392ms/step
# [INFO] processing batch 234/469
# 1/1 [==============================] - 0s 393ms/step
# [INFO] processing batch 235/469
# 1/1 [==============================] - 0s 391ms/step
# [INFO] processing batch 236/469
# 1/1 [==============================] - 0s 392ms/step
# [INFO] processing batch 237/469
# 1/1 [==============================] - 0s 411ms/step
# [INFO] processing batch 238/469
# 1/1 [==============================] - 0s 398ms/step
# [INFO] processing batch 239/469
# 1/1 [==============================] - 0s 400ms/step
# [INFO] processing batch 240/469
# 1/1 [==============================] - 0s 389ms/step
# [INFO] processing batch 241/469
# 1/1 [==============================] - 0s 398ms/step
# [INFO] processing batch 242/469
# 1/1 [==============================] - 0s 393ms/step
# [INFO] processing batch 243/469
# 1/1 [==============================] - 0s 392ms/step
# [INFO] processing batch 244/469
# 1/1 [==============================] - 0s 391ms/step
# [INFO] processing batch 245/469
# 1/1 [==============================] - 0s 394ms/step
# [INFO] processing batch 246/469
# 1/1 [==============================] - 0s 431ms/step
# [INFO] processing batch 247/469
# 1/1 [==============================] - 0s 436ms/step
# [INFO] processing batch 248/469
# 1/1 [==============================] - 0s 427ms/step
# [INFO] processing batch 249/469
# 1/1 [==============================] - 0s 461ms/step
# [INFO] processing batch 250/469
# 1/1 [==============================] - 0s 430ms/step
# [INFO] processing batch 251/469
# 1/1 [==============================] - 0s 472ms/step
# [INFO] processing batch 252/469
# 1/1 [==============================] - 0s 420ms/step
# [INFO] processing batch 253/469
# 1/1 [==============================] - 0s 457ms/step
# [INFO] processing batch 254/469
# 1/1 [==============================] - 0s 403ms/step
# [INFO] processing batch 255/469
# 1/1 [==============================] - 0s 459ms/step
# [INFO] processing batch 256/469
# 1/1 [==============================] - 0s 412ms/step
# [INFO] processing batch 257/469
# 1/1 [==============================] - 0s 417ms/step
# [INFO] processing batch 258/469
# 1/1 [==============================] - 0s 424ms/step
# [INFO] processing batch 259/469
# 1/1 [==============================] - 0s 431ms/step
# [INFO] processing batch 260/469
# 1/1 [==============================] - 0s 423ms/step
# [INFO] processing batch 261/469
# 1/1 [==============================] - 0s 417ms/step
# [INFO] processing batch 262/469
# 1/1 [==============================] - 0s 394ms/step
# [INFO] processing batch 263/469
# 1/1 [==============================] - 0s 391ms/step
# [INFO] processing batch 264/469
# 1/1 [==============================] - 0s 400ms/step
# [INFO] processing batch 265/469
# 1/1 [==============================] - 0s 388ms/step
# [INFO] processing batch 266/469
# 1/1 [==============================] - 0s 424ms/step
# [INFO] processing batch 267/469
# 1/1 [==============================] - 0s 405ms/step
# [INFO] processing batch 268/469
# 1/1 [==============================] - 0s 407ms/step
# [INFO] processing batch 269/469
# 1/1 [==============================] - 0s 400ms/step
# [INFO] processing batch 270/469
# 1/1 [==============================] - 0s 400ms/step
# [INFO] processing batch 271/469
# 1/1 [==============================] - 0s 398ms/step
# [INFO] processing batch 272/469
# 1/1 [==============================] - 0s 475ms/step
# [INFO] processing batch 273/469
# 1/1 [==============================] - 0s 407ms/step
# [INFO] processing batch 274/469
# 1/1 [==============================] - 0s 397ms/step
# [INFO] processing batch 275/469
# 1/1 [==============================] - 0s 403ms/step
# [INFO] processing batch 276/469
# 1/1 [==============================] - 0s 399ms/step
# [INFO] processing batch 277/469
# 1/1 [==============================] - 0s 410ms/step
# [INFO] processing batch 278/469
# 1/1 [==============================] - 0s 394ms/step
# [INFO] processing batch 279/469
# 1/1 [==============================] - 0s 397ms/step
# [INFO] processing batch 280/469
# 1/1 [==============================] - 0s 390ms/step
# [INFO] processing batch 281/469
# 1/1 [==============================] - 0s 404ms/step
# [INFO] processing batch 282/469
# 1/1 [==============================] - 0s 417ms/step
# [INFO] processing batch 283/469
# 1/1 [==============================] - 0s 402ms/step
# [INFO] processing batch 284/469
# 1/1 [==============================] - 0s 415ms/step
# [INFO] processing batch 285/469
# 1/1 [==============================] - 0s 402ms/step
# [INFO] processing batch 286/469
# 1/1 [==============================] - 0s 400ms/step
# [INFO] processing batch 287/469
# 1/1 [==============================] - 0s 412ms/step
# [INFO] processing batch 288/469
# 1/1 [==============================] - 0s 412ms/step
# [INFO] processing batch 289/469
# 1/1 [==============================] - 0s 410ms/step
# [INFO] processing batch 290/469
# 1/1 [==============================] - 0s 395ms/step
# [INFO] processing batch 291/469
# 1/1 [==============================] - 0s 407ms/step
# [INFO] processing batch 292/469
# 1/1 [==============================] - 0s 402ms/step
# [INFO] processing batch 293/469
# 1/1 [==============================] - 0s 400ms/step
# [INFO] processing batch 294/469
# 1/1 [==============================] - 0s 406ms/step
# [INFO] processing batch 295/469
# 1/1 [==============================] - 0s 408ms/step
# [INFO] processing batch 296/469
# 1/1 [==============================] - 0s 421ms/step
# [INFO] processing batch 297/469
# 1/1 [==============================] - 0s 394ms/step
# [INFO] processing batch 298/469
# 1/1 [==============================] - 0s 402ms/step
# [INFO] processing batch 299/469
# 1/1 [==============================] - 0s 392ms/step
# [INFO] processing batch 300/469
# 1/1 [==============================] - 0s 399ms/step
# [INFO] processing batch 301/469
# 1/1 [==============================] - 0s 397ms/step
# [INFO] processing batch 302/469
# 1/1 [==============================] - 0s 403ms/step
# [INFO] processing batch 303/469
# 1/1 [==============================] - 0s 396ms/step
# [INFO] processing batch 304/469
# 1/1 [==============================] - 0s 414ms/step
# [INFO] processing batch 305/469
# 1/1 [==============================] - 0s 417ms/step
# [INFO] processing batch 306/469
# 1/1 [==============================] - 0s 408ms/step
# [INFO] processing batch 307/469
# 1/1 [==============================] - 0s 401ms/step
# [INFO] processing batch 308/469
# 1/1 [==============================] - 0s 401ms/step
# [INFO] processing batch 309/469
# 1/1 [==============================] - 0s 399ms/step
# [INFO] processing batch 310/469
# 1/1 [==============================] - 0s 396ms/step
# [INFO] processing batch 311/469
# 1/1 [==============================] - 0s 438ms/step
# [INFO] processing batch 312/469
# 1/1 [==============================] - 0s 422ms/step
# [INFO] processing batch 313/469
# 1/1 [==============================] - 0s 398ms/step
# [INFO] processing batch 314/469
# 1/1 [==============================] - 0s 404ms/step
# [INFO] processing batch 315/469
# 1/1 [==============================] - 0s 426ms/step
# [INFO] processing batch 316/469
# 1/1 [==============================] - 0s 392ms/step
# [INFO] processing batch 317/469
# 1/1 [==============================] - 0s 391ms/step
# [INFO] processing batch 318/469
# 1/1 [==============================] - 0s 414ms/step
# [INFO] processing batch 319/469
# 1/1 [==============================] - 0s 408ms/step
# [INFO] processing batch 320/469
# 1/1 [==============================] - 0s 468ms/step
# [INFO] processing batch 321/469
# 1/1 [==============================] - 0s 401ms/step
# [INFO] processing batch 322/469
# 1/1 [==============================] - 0s 396ms/step
# [INFO] processing batch 323/469
# 1/1 [==============================] - 0s 408ms/step
# [INFO] processing batch 324/469
# 1/1 [==============================] - 0s 414ms/step
# [INFO] processing batch 325/469
# 1/1 [==============================] - 0s 419ms/step
# [INFO] processing batch 326/469
# 1/1 [==============================] - 0s 399ms/step
# [INFO] processing batch 327/469
# 1/1 [==============================] - 0s 392ms/step
# [INFO] processing batch 328/469
# 1/1 [==============================] - 0s 421ms/step
# [INFO] processing batch 329/469
# 1/1 [==============================] - 0s 406ms/step
# [INFO] processing batch 330/469
# 1/1 [==============================] - 0s 401ms/step
# [INFO] processing batch 331/469
# 1/1 [==============================] - 0s 402ms/step
# [INFO] processing batch 332/469
# 1/1 [==============================] - 0s 399ms/step
# [INFO] processing batch 333/469
# 1/1 [==============================] - 0s 405ms/step
# [INFO] processing batch 334/469
# 1/1 [==============================] - 0s 402ms/step
# [INFO] processing batch 335/469
# 1/1 [==============================] - 0s 442ms/step
# [INFO] processing batch 336/469
# 1/1 [==============================] - 0s 430ms/step
# [INFO] processing batch 337/469
# 1/1 [==============================] - 0s 404ms/step
# [INFO] processing batch 338/469
# 1/1 [==============================] - 0s 401ms/step
# [INFO] processing batch 339/469
# 1/1 [==============================] - 0s 403ms/step
# [INFO] processing batch 340/469
# 1/1 [==============================] - 0s 433ms/step
# [INFO] processing batch 341/469
# 1/1 [==============================] - 0s 405ms/step
# [INFO] processing batch 342/469
# 1/1 [==============================] - 0s 449ms/step
# [INFO] processing batch 343/469
# 1/1 [==============================] - 0s 412ms/step
# [INFO] processing batch 344/469
# 1/1 [==============================] - 0s 396ms/step
# [INFO] processing batch 345/469
# 1/1 [==============================] - 0s 414ms/step
# [INFO] processing batch 346/469
# 1/1 [==============================] - 0s 405ms/step
# [INFO] processing batch 347/469
# 1/1 [==============================] - 0s 397ms/step
# [INFO] processing batch 348/469
# 1/1 [==============================] - 0s 420ms/step
# [INFO] processing batch 349/469
# 1/1 [==============================] - 0s 423ms/step
# [INFO] processing batch 350/469
# 1/1 [==============================] - 0s 414ms/step
# [INFO] processing batch 351/469
# 1/1 [==============================] - 0s 429ms/step
# [INFO] processing batch 352/469
# 1/1 [==============================] - 0s 450ms/step
# [INFO] processing batch 353/469
# 1/1 [==============================] - 0s 443ms/step
# [INFO] processing batch 354/469
# 1/1 [==============================] - 0s 428ms/step
# [INFO] processing batch 355/469
# 1/1 [==============================] - 0s 439ms/step
# [INFO] processing batch 356/469
# 1/1 [==============================] - 0s 391ms/step
# [INFO] processing batch 357/469
# 1/1 [==============================] - 0s 440ms/step
# [INFO] processing batch 358/469
# 1/1 [==============================] - 0s 418ms/step
# [INFO] processing batch 359/469
# 1/1 [==============================] - 0s 405ms/step
# [INFO] processing batch 360/469
# 1/1 [==============================] - 0s 416ms/step
# [INFO] processing batch 361/469
# 1/1 [==============================] - 0s 408ms/step
# [INFO] processing batch 362/469
# 1/1 [==============================] - 0s 416ms/step
# [INFO] processing batch 363/469
# 1/1 [==============================] - 0s 396ms/step
# [INFO] processing batch 364/469
# 1/1 [==============================] - 0s 411ms/step
# [INFO] processing batch 365/469
# 1/1 [==============================] - 0s 403ms/step
# [INFO] processing batch 366/469
# 1/1 [==============================] - 0s 400ms/step
# [INFO] processing batch 367/469
# 1/1 [==============================] - 0s 400ms/step
# [INFO] processing batch 368/469
# 1/1 [==============================] - 0s 408ms/step
# [INFO] processing batch 369/469
# 1/1 [==============================] - 0s 408ms/step
# [INFO] processing batch 370/469
# 1/1 [==============================] - 0s 422ms/step
# [INFO] processing batch 371/469
# 1/1 [==============================] - 0s 423ms/step
# [INFO] processing batch 372/469
# 1/1 [==============================] - 0s 428ms/step
# [INFO] processing batch 373/469
# 1/1 [==============================] - 0s 400ms/step
# [INFO] processing batch 374/469
# 1/1 [==============================] - 0s 400ms/step
# [INFO] processing batch 375/469
# 1/1 [==============================] - 0s 405ms/step
# [INFO] processing batch 376/469
# 1/1 [==============================] - 0s 405ms/step
# [INFO] processing batch 377/469
# 1/1 [==============================] - 0s 403ms/step
# [INFO] processing batch 378/469
# 1/1 [==============================] - 0s 408ms/step
# [INFO] processing batch 379/469
# 1/1 [==============================] - 0s 406ms/step
# [INFO] processing batch 380/469
# 1/1 [==============================] - 0s 430ms/step
# [INFO] processing batch 381/469
# 1/1 [==============================] - 0s 418ms/step
# [INFO] processing batch 382/469
# 1/1 [==============================] - 0s 401ms/step
# [INFO] processing batch 383/469
# 1/1 [==============================] - 0s 485ms/step
# [INFO] processing batch 384/469
# 1/1 [==============================] - 0s 430ms/step
# [INFO] processing batch 385/469
# 1/1 [==============================] - 0s 394ms/step
# [INFO] processing batch 386/469
# 1/1 [==============================] - 0s 403ms/step
# [INFO] processing batch 387/469
# 1/1 [==============================] - 0s 404ms/step
# [INFO] processing batch 388/469
# 1/1 [==============================] - 0s 398ms/step
# [INFO] processing batch 389/469
# 1/1 [==============================] - 0s 406ms/step
# [INFO] processing batch 390/469
# 1/1 [==============================] - 0s 417ms/step
# [INFO] processing batch 391/469
# 1/1 [==============================] - 0s 440ms/step
# [INFO] processing batch 392/469
# 1/1 [==============================] - 0s 421ms/step
# [INFO] processing batch 393/469
# 1/1 [==============================] - 0s 397ms/step
# [INFO] processing batch 394/469
# 1/1 [==============================] - 0s 417ms/step
# [INFO] processing batch 395/469
# 1/1 [==============================] - 0s 430ms/step
# [INFO] processing batch 396/469
# 1/1 [==============================] - 0s 395ms/step
# [INFO] processing batch 397/469
# 1/1 [==============================] - 0s 396ms/step
# [INFO] processing batch 398/469
# 1/1 [==============================] - 0s 463ms/step
# [INFO] processing batch 399/469
# 1/1 [==============================] - 0s 411ms/step
# [INFO] processing batch 400/469
# 1/1 [==============================] - 0s 449ms/step
# [INFO] processing batch 401/469
# 1/1 [==============================] - 0s 398ms/step
# [INFO] processing batch 402/469
# 1/1 [==============================] - 0s 395ms/step
# [INFO] processing batch 403/469
# 1/1 [==============================] - 0s 395ms/step
# [INFO] processing batch 404/469
# 1/1 [==============================] - 0s 427ms/step
# [INFO] processing batch 405/469
# 1/1 [==============================] - 0s 410ms/step
# [INFO] processing batch 406/469
# 1/1 [==============================] - 0s 405ms/step
# [INFO] processing batch 407/469
# 1/1 [==============================] - 0s 416ms/step
# [INFO] processing batch 408/469
# 1/1 [==============================] - 0s 431ms/step
# [INFO] processing batch 409/469
# 1/1 [==============================] - 1s 509ms/step
# [INFO] processing batch 410/469
# 1/1 [==============================] - 0s 400ms/step
# [INFO] processing batch 411/469
# 1/1 [==============================] - 0s 454ms/step
# [INFO] processing batch 412/469
# 1/1 [==============================] - 0s 423ms/step
# [INFO] processing batch 413/469
# 1/1 [==============================] - 0s 423ms/step
# [INFO] processing batch 414/469
# 1/1 [==============================] - 0s 444ms/step
# [INFO] processing batch 415/469
# 1/1 [==============================] - 0s 415ms/step
# [INFO] processing batch 416/469
# 1/1 [==============================] - 0s 414ms/step
# [INFO] processing batch 417/469
# 1/1 [==============================] - 0s 432ms/step
# [INFO] processing batch 418/469
# 1/1 [==============================] - 0s 418ms/step
# [INFO] processing batch 419/469
# 1/1 [==============================] - 0s 462ms/step
# [INFO] processing batch 420/469
# 1/1 [==============================] - 0s 406ms/step
# [INFO] processing batch 421/469
# 1/1 [==============================] - 0s 448ms/step
# [INFO] processing batch 422/469
# 1/1 [==============================] - 0s 416ms/step
# [INFO] processing batch 423/469
# 1/1 [==============================] - 0s 420ms/step
# [INFO] processing batch 424/469
# 1/1 [==============================] - 0s 423ms/step
# [INFO] processing batch 425/469
# 1/1 [==============================] - 0s 403ms/step
# [INFO] processing batch 426/469
# 1/1 [==============================] - 0s 425ms/step
# [INFO] processing batch 427/469
# 1/1 [==============================] - 0s 441ms/step
# [INFO] processing batch 428/469
# 1/1 [==============================] - 0s 460ms/step
# [INFO] processing batch 429/469
# 1/1 [==============================] - 0s 400ms/step
# [INFO] processing batch 430/469
# 1/1 [==============================] - 0s 404ms/step
# [INFO] processing batch 431/469
# 1/1 [==============================] - 0s 409ms/step
# [INFO] processing batch 432/469
# 1/1 [==============================] - 0s 401ms/step
# [INFO] processing batch 433/469
# 1/1 [==============================] - 0s 395ms/step
# [INFO] processing batch 434/469
# 1/1 [==============================] - 0s 394ms/step
# [INFO] processing batch 435/469
# 1/1 [==============================] - 0s 398ms/step
# [INFO] processing batch 436/469
# 1/1 [==============================] - 0s 392ms/step
# [INFO] processing batch 437/469
# 1/1 [==============================] - 0s 395ms/step
# [INFO] processing batch 438/469
# 1/1 [==============================] - 0s 403ms/step
# [INFO] processing batch 439/469
# 1/1 [==============================] - 0s 392ms/step
# [INFO] processing batch 440/469
# 1/1 [==============================] - 0s 396ms/step
# [INFO] processing batch 441/469
# 1/1 [==============================] - 0s 394ms/step
# [INFO] processing batch 442/469
# 1/1 [==============================] - 0s 389ms/step
# [INFO] processing batch 443/469
# 1/1 [==============================] - 0s 403ms/step
# [INFO] processing batch 444/469
# 1/1 [==============================] - 0s 396ms/step
# [INFO] processing batch 445/469
# 1/1 [==============================] - 0s 422ms/step
# [INFO] processing batch 446/469
# 1/1 [==============================] - 0s 393ms/step
# [INFO] processing batch 447/469
# 1/1 [==============================] - 0s 400ms/step
# [INFO] processing batch 448/469
# 1/1 [==============================] - 0s 386ms/step
# [INFO] processing batch 449/469
# 1/1 [==============================] - 0s 390ms/step
# [INFO] processing batch 450/469
# 1/1 [==============================] - 0s 381ms/step
# [INFO] processing batch 451/469
# 1/1 [==============================] - 0s 420ms/step
# [INFO] processing batch 452/469
# 1/1 [==============================] - 0s 391ms/step
# [INFO] processing batch 453/469
# 1/1 [==============================] - 0s 425ms/step
# [INFO] processing batch 454/469
# 1/1 [==============================] - 0s 397ms/step
# [INFO] processing batch 455/469
# 1/1 [==============================] - 0s 409ms/step
# [INFO] processing batch 456/469
# 1/1 [==============================] - 0s 398ms/step
# [INFO] processing batch 457/469
# 1/1 [==============================] - 0s 391ms/step
# [INFO] processing batch 458/469
# 1/1 [==============================] - 0s 420ms/step
# [INFO] processing batch 459/469
# 1/1 [==============================] - 0s 415ms/step
# [INFO] processing batch 460/469
# 1/1 [==============================] - 0s 428ms/step
# [INFO] processing batch 461/469
# 1/1 [==============================] - 0s 410ms/step
# [INFO] processing batch 462/469
# 1/1 [==============================] - 0s 424ms/step
# [INFO] processing batch 463/469
# 1/1 [==============================] - 0s 394ms/step
# [INFO] processing batch 464/469
# 1/1 [==============================] - 0s 411ms/step
# [INFO] processing batch 465/469
# 1/1 [==============================] - 0s 412ms/step
# [INFO] processing batch 466/469
# 1/1 [==============================] - 0s 419ms/step
# [INFO] processing batch 467/469
# 1/1 [==============================] - 0s 382ms/step
# [INFO] processing batch 468/469
# 1/1 [==============================] - 0s 408ms/step
# [INFO] processing batch 469/469
# 1/1 [==============================] - 1s 648ms/step
# [INFO] processing test split...
# [INFO] processing batch 1/201
# 1/1 [==============================] - 0s 400ms/step
# [INFO] processing batch 2/201
# 1/1 [==============================] - 0s 415ms/step
# [INFO] processing batch 3/201
# 1/1 [==============================] - 0s 408ms/step
# [INFO] processing batch 4/201
# 1/1 [==============================] - 0s 408ms/step
# [INFO] processing batch 5/201
# 1/1 [==============================] - 0s 410ms/step
# [INFO] processing batch 6/201
# 1/1 [==============================] - 0s 405ms/step
# [INFO] processing batch 7/201
# 1/1 [==============================] - 0s 453ms/step
# [INFO] processing batch 8/201
# 1/1 [==============================] - 0s 427ms/step
# [INFO] processing batch 9/201
# 1/1 [==============================] - 0s 434ms/step
# [INFO] processing batch 10/201
# 1/1 [==============================] - 0s 410ms/step
# [INFO] processing batch 11/201
# 1/1 [==============================] - 0s 409ms/step
# [INFO] processing batch 12/201
# 1/1 [==============================] - 0s 414ms/step
# [INFO] processing batch 13/201
# 1/1 [==============================] - 0s 406ms/step
# [INFO] processing batch 14/201
# 1/1 [==============================] - 0s 434ms/step
# [INFO] processing batch 15/201
# 1/1 [==============================] - 0s 423ms/step
# [INFO] processing batch 16/201
# 1/1 [==============================] - 0s 412ms/step
# [INFO] processing batch 17/201
# 1/1 [==============================] - 0s 413ms/step
# [INFO] processing batch 18/201
# 1/1 [==============================] - 0s 393ms/step
# [INFO] processing batch 19/201
# 1/1 [==============================] - 0s 401ms/step
# [INFO] processing batch 20/201
# 1/1 [==============================] - 0s 405ms/step
# [INFO] processing batch 21/201
# 1/1 [==============================] - 0s 417ms/step
# [INFO] processing batch 22/201
# 1/1 [==============================] - 0s 400ms/step
# [INFO] processing batch 23/201
# 1/1 [==============================] - 0s 402ms/step
# [INFO] processing batch 24/201
# 1/1 [==============================] - 0s 389ms/step
# [INFO] processing batch 25/201
# 1/1 [==============================] - 0s 392ms/step
# [INFO] processing batch 26/201
# 1/1 [==============================] - 0s 409ms/step
# [INFO] processing batch 27/201
# 1/1 [==============================] - 0s 445ms/step
# [INFO] processing batch 28/201
# 1/1 [==============================] - 0s 424ms/step
# [INFO] processing batch 29/201
# 1/1 [==============================] - 0s 465ms/step
# [INFO] processing batch 30/201
# 1/1 [==============================] - 0s 417ms/step
# [INFO] processing batch 31/201
# 1/1 [==============================] - 0s 408ms/step
# [INFO] processing batch 32/201
# 1/1 [==============================] - 0s 406ms/step
# [INFO] processing batch 33/201
# 1/1 [==============================] - 0s 410ms/step
# [INFO] processing batch 34/201
# 1/1 [==============================] - 0s 409ms/step
# [INFO] processing batch 35/201
# 1/1 [==============================] - 0s 434ms/step
# [INFO] processing batch 36/201
# 1/1 [==============================] - 0s 458ms/step
# [INFO] processing batch 37/201
# 1/1 [==============================] - 0s 445ms/step
# [INFO] processing batch 38/201
# 1/1 [==============================] - 0s 428ms/step
# [INFO] processing batch 39/201
# 1/1 [==============================] - 0s 407ms/step
# [INFO] processing batch 40/201
# 1/1 [==============================] - 0s 428ms/step
# [INFO] processing batch 41/201
# 1/1 [==============================] - 0s 412ms/step
# [INFO] processing batch 42/201
# 1/1 [==============================] - 0s 478ms/step
# [INFO] processing batch 43/201
# 1/1 [==============================] - 0s 452ms/step
# [INFO] processing batch 44/201
# 1/1 [==============================] - 0s 438ms/step
# [INFO] processing batch 45/201
# 1/1 [==============================] - 0s 446ms/step
# [INFO] processing batch 46/201
# 1/1 [==============================] - 0s 449ms/step
# [INFO] processing batch 47/201
# 1/1 [==============================] - 0s 434ms/step
# [INFO] processing batch 48/201
# 1/1 [==============================] - 0s 434ms/step
# [INFO] processing batch 49/201
# 1/1 [==============================] - 0s 418ms/step
# [INFO] processing batch 50/201
# 1/1 [==============================] - 0s 439ms/step
# [INFO] processing batch 51/201
# 1/1 [==============================] - 0s 415ms/step
# [INFO] processing batch 52/201
# 1/1 [==============================] - 0s 432ms/step
# [INFO] processing batch 53/201
# 1/1 [==============================] - 0s 437ms/step
# [INFO] processing batch 54/201
# 1/1 [==============================] - 0s 428ms/step
# [INFO] processing batch 55/201
# 1/1 [==============================] - 0s 413ms/step
# [INFO] processing batch 56/201
# 1/1 [==============================] - 0s 441ms/step
# [INFO] processing batch 57/201
# 1/1 [==============================] - 0s 397ms/step
# [INFO] processing batch 58/201
# 1/1 [==============================] - 0s 393ms/step
# [INFO] processing batch 59/201
# 1/1 [==============================] - 0s 417ms/step
# [INFO] processing batch 60/201
# 1/1 [==============================] - 0s 405ms/step
# [INFO] processing batch 61/201
# 1/1 [==============================] - 0s 420ms/step
# [INFO] processing batch 62/201
# 1/1 [==============================] - 0s 421ms/step
# [INFO] processing batch 63/201
# 1/1 [==============================] - 0s 431ms/step
# [INFO] processing batch 64/201
# 1/1 [==============================] - 0s 429ms/step
# [INFO] processing batch 65/201
# 1/1 [==============================] - 0s 402ms/step
# [INFO] processing batch 66/201
# 1/1 [==============================] - 0s 411ms/step
# [INFO] processing batch 67/201
# 1/1 [==============================] - 0s 411ms/step
# [INFO] processing batch 68/201
# 1/1 [==============================] - 0s 408ms/step
# [INFO] processing batch 69/201
# 1/1 [==============================] - 0s 416ms/step
# [INFO] processing batch 70/201
# 1/1 [==============================] - 0s 403ms/step
# [INFO] processing batch 71/201
# 1/1 [==============================] - 0s 407ms/step
# [INFO] processing batch 72/201
# 1/1 [==============================] - 0s 405ms/step
# [INFO] processing batch 73/201
# 1/1 [==============================] - 0s 408ms/step
# [INFO] processing batch 74/201
# 1/1 [==============================] - 0s 414ms/step
# [INFO] processing batch 75/201
# 1/1 [==============================] - 0s 415ms/step
# [INFO] processing batch 76/201
# 1/1 [==============================] - 0s 405ms/step
# [INFO] processing batch 77/201
# 1/1 [==============================] - 0s 396ms/step
# [INFO] processing batch 78/201
# 1/1 [==============================] - 0s 406ms/step
# [INFO] processing batch 79/201
# 1/1 [==============================] - 0s 397ms/step
# [INFO] processing batch 80/201
# 1/1 [==============================] - 0s 394ms/step
# [INFO] processing batch 81/201
# 1/1 [==============================] - 0s 395ms/step
# [INFO] processing batch 82/201
# 1/1 [==============================] - 0s 401ms/step
# [INFO] processing batch 83/201
# 1/1 [==============================] - 0s 405ms/step
# [INFO] processing batch 84/201
# 1/1 [==============================] - 0s 464ms/step
# [INFO] processing batch 85/201
# 1/1 [==============================] - 0s 395ms/step
# [INFO] processing batch 86/201
# 1/1 [==============================] - 0s 399ms/step
# [INFO] processing batch 87/201
# 1/1 [==============================] - 0s 418ms/step
# [INFO] processing batch 88/201
# 1/1 [==============================] - 0s 438ms/step
# [INFO] processing batch 89/201
# 1/1 [==============================] - 0s 418ms/step
# [INFO] processing batch 90/201
# 1/1 [==============================] - 0s 411ms/step
# [INFO] processing batch 91/201
# 1/1 [==============================] - 0s 395ms/step
# [INFO] processing batch 92/201
# 1/1 [==============================] - 0s 425ms/step
# [INFO] processing batch 93/201
# 1/1 [==============================] - 0s 463ms/step
# [INFO] processing batch 94/201
# 1/1 [==============================] - 0s 414ms/step
# [INFO] processing batch 95/201
# 1/1 [==============================] - 0s 419ms/step
# [INFO] processing batch 96/201
# 1/1 [==============================] - 0s 460ms/step
# [INFO] processing batch 97/201
# 1/1 [==============================] - 0s 436ms/step
# [INFO] processing batch 98/201
# 1/1 [==============================] - 0s 406ms/step
# [INFO] processing batch 99/201
# 1/1 [==============================] - 0s 409ms/step
# [INFO] processing batch 100/201
# 1/1 [==============================] - 0s 411ms/step
# [INFO] processing batch 101/201
# 1/1 [==============================] - 0s 426ms/step
# [INFO] processing batch 102/201
# 1/1 [==============================] - 0s 489ms/step
# [INFO] processing batch 103/201
# 1/1 [==============================] - 0s 412ms/step
# [INFO] processing batch 104/201
# 1/1 [==============================] - 0s 421ms/step
# [INFO] processing batch 105/201
# 1/1 [==============================] - 0s 400ms/step
# [INFO] processing batch 106/201
# 1/1 [==============================] - 0s 396ms/step
# [INFO] processing batch 107/201
# 1/1 [==============================] - 0s 400ms/step
# [INFO] processing batch 108/201
# 1/1 [==============================] - 0s 399ms/step
# [INFO] processing batch 109/201
# 1/1 [==============================] - 0s 471ms/step
# [INFO] processing batch 110/201
# 1/1 [==============================] - 0s 400ms/step
# [INFO] processing batch 111/201
# 1/1 [==============================] - 0s 400ms/step
# [INFO] processing batch 112/201
# 1/1 [==============================] - 0s 397ms/step
# [INFO] processing batch 113/201
# 1/1 [==============================] - 0s 406ms/step
# [INFO] processing batch 114/201
# 1/1 [==============================] - 0s 405ms/step
# [INFO] processing batch 115/201
# 1/1 [==============================] - 0s 400ms/step
# [INFO] processing batch 116/201
# 1/1 [==============================] - 0s 413ms/step
# [INFO] processing batch 117/201
# 1/1 [==============================] - 0s 389ms/step
# [INFO] processing batch 118/201
# 1/1 [==============================] - 0s 400ms/step
# [INFO] processing batch 119/201
# 1/1 [==============================] - 0s 393ms/step
# [INFO] processing batch 120/201
# 1/1 [==============================] - 0s 397ms/step
# [INFO] processing batch 121/201
# 1/1 [==============================] - 0s 405ms/step
# [INFO] processing batch 122/201
# 1/1 [==============================] - 0s 416ms/step
# [INFO] processing batch 123/201
# 1/1 [==============================] - 0s 408ms/step
# [INFO] processing batch 124/201
# 1/1 [==============================] - 0s 410ms/step
# [INFO] processing batch 125/201
# 1/1 [==============================] - 0s 399ms/step
# [INFO] processing batch 126/201
# 1/1 [==============================] - 0s 404ms/step
# [INFO] processing batch 127/201
# 1/1 [==============================] - 0s 414ms/step
# [INFO] processing batch 128/201
# 1/1 [==============================] - 0s 396ms/step
# [INFO] processing batch 129/201
# 1/1 [==============================] - 0s 406ms/step
# [INFO] processing batch 130/201
# 1/1 [==============================] - 0s 409ms/step
# [INFO] processing batch 131/201
# 1/1 [==============================] - 0s 403ms/step
# [INFO] processing batch 132/201
# 1/1 [==============================] - 0s 439ms/step
# [INFO] processing batch 133/201
# 1/1 [==============================] - 0s 430ms/step
# [INFO] processing batch 134/201
# 1/1 [==============================] - 0s 405ms/step
# [INFO] processing batch 135/201
# 1/1 [==============================] - 0s 404ms/step
# [INFO] processing batch 136/201
# 1/1 [==============================] - 0s 417ms/step
# [INFO] processing batch 137/201
# 1/1 [==============================] - 0s 404ms/step
# [INFO] processing batch 138/201
# 1/1 [==============================] - 0s 403ms/step
# [INFO] processing batch 139/201
# 1/1 [==============================] - 0s 401ms/step
# [INFO] processing batch 140/201
# 1/1 [==============================] - 0s 391ms/step
# [INFO] processing batch 141/201
# 1/1 [==============================] - 0s 413ms/step
# [INFO] processing batch 142/201
# 1/1 [==============================] - 0s 414ms/step
# [INFO] processing batch 143/201
# 1/1 [==============================] - 0s 414ms/step
# [INFO] processing batch 144/201
# 1/1 [==============================] - 0s 410ms/step
# [INFO] processing batch 145/201
# 1/1 [==============================] - 0s 447ms/step
# [INFO] processing batch 146/201
# 1/1 [==============================] - 0s 424ms/step
# [INFO] processing batch 147/201
# 1/1 [==============================] - 0s 427ms/step
# [INFO] processing batch 148/201
# 1/1 [==============================] - 0s 404ms/step
# [INFO] processing batch 149/201
# 1/1 [==============================] - 0s 404ms/step
# [INFO] processing batch 150/201
# 1/1 [==============================] - 0s 400ms/step
# [INFO] processing batch 151/201
# 1/1 [==============================] - 0s 443ms/step
# [INFO] processing batch 152/201
# 1/1 [==============================] - 0s 435ms/step
# [INFO] processing batch 153/201
# 1/1 [==============================] - 0s 425ms/step
# [INFO] processing batch 154/201
# 1/1 [==============================] - 0s 477ms/step
# [INFO] processing batch 155/201
# 1/1 [==============================] - 0s 457ms/step
# [INFO] processing batch 156/201
# 1/1 [==============================] - 0s 420ms/step
# [INFO] processing batch 157/201
# 1/1 [==============================] - 0s 430ms/step
# [INFO] processing batch 158/201
# 1/1 [==============================] - 0s 408ms/step
# [INFO] processing batch 159/201
# 1/1 [==============================] - 0s 444ms/step
# [INFO] processing batch 160/201
# 1/1 [==============================] - 0s 427ms/step
# [INFO] processing batch 161/201
# 1/1 [==============================] - 0s 424ms/step
# [INFO] processing batch 162/201
# 1/1 [==============================] - 0s 408ms/step
# [INFO] processing batch 163/201
# 1/1 [==============================] - 0s 437ms/step
# [INFO] processing batch 164/201
# 1/1 [==============================] - 0s 496ms/step
# [INFO] processing batch 165/201
# 1/1 [==============================] - 0s 419ms/step
# [INFO] processing batch 166/201
# 1/1 [==============================] - 0s 397ms/step
# [INFO] processing batch 167/201
# 1/1 [==============================] - 0s 403ms/step
# [INFO] processing batch 168/201
# 1/1 [==============================] - 0s 395ms/step
# [INFO] processing batch 169/201
# 1/1 [==============================] - 0s 411ms/step
# [INFO] processing batch 170/201
# 1/1 [==============================] - 0s 424ms/step
# [INFO] processing batch 171/201
# 1/1 [==============================] - 0s 429ms/step
# [INFO] processing batch 172/201
# 1/1 [==============================] - 0s 431ms/step
# [INFO] processing batch 173/201
# 1/1 [==============================] - 0s 441ms/step
# [INFO] processing batch 174/201
# 1/1 [==============================] - 0s 399ms/step
# [INFO] processing batch 175/201
# 1/1 [==============================] - 0s 412ms/step
# [INFO] processing batch 176/201
# 1/1 [==============================] - 0s 423ms/step
# [INFO] processing batch 177/201
# 1/1 [==============================] - 0s 422ms/step
# [INFO] processing batch 178/201
# 1/1 [==============================] - 0s 439ms/step
# [INFO] processing batch 179/201
# 1/1 [==============================] - 0s 422ms/step
# [INFO] processing batch 180/201
# 1/1 [==============================] - 0s 421ms/step
# [INFO] processing batch 181/201
# 1/1 [==============================] - 0s 406ms/step
# [INFO] processing batch 182/201
# 1/1 [==============================] - 0s 425ms/step
# [INFO] processing batch 183/201
# 1/1 [==============================] - 0s 406ms/step
# [INFO] processing batch 184/201
# 1/1 [==============================] - 0s 400ms/step
# [INFO] processing batch 185/201
# 1/1 [==============================] - 0s 440ms/step
# [INFO] processing batch 186/201
# 1/1 [==============================] - 0s 400ms/step
# [INFO] processing batch 187/201
# 1/1 [==============================] - 0s 455ms/step
# [INFO] processing batch 188/201
# 1/1 [==============================] - 0s 470ms/step
# [INFO] processing batch 189/201
# 1/1 [==============================] - 0s 446ms/step
# [INFO] processing batch 190/201
# 1/1 [==============================] - 1s 525ms/step
# [INFO] processing batch 191/201
# 1/1 [==============================] - 0s 466ms/step
# [INFO] processing batch 192/201
# 1/1 [==============================] - 0s 436ms/step
# [INFO] processing batch 193/201
# 1/1 [==============================] - 0s 457ms/step
# [INFO] processing batch 194/201
# 1/1 [==============================] - 0s 467ms/step
# [INFO] processing batch 195/201
# 1/1 [==============================] - 0s 454ms/step
# [INFO] processing batch 196/201
# 1/1 [==============================] - 0s 412ms/step
# [INFO] processing batch 197/201
# 1/1 [==============================] - 0s 444ms/step
# [INFO] processing batch 198/201
# 1/1 [==============================] - 0s 417ms/step
# [INFO] processing batch 199/201
# 1/1 [==============================] - 0s 425ms/step
# [INFO] processing batch 200/201
# 1/1 [==============================] - 0s 405ms/step
# [INFO] processing batch 201/201
# 1/1 [==============================] - 0s 233ms/step

# %% [markdown]
# ## Preparing the Data for Train, Validation and Test
#
# Loading generated image features and splitting them into train, validation and test.
#
# The train set will be used for training and validation.
# The validation set will be used for testing.
#
# Naming Convention
#
# | Data Split | X         | y         | y (one-hot-encoded) |
# | :--------- | :-------- | :-------- | :------------------ |
# | Training   | `X_train` | `y_train` | `Y_train`           |
# | Validation | `X_val`   | `y_val`   | `Y_val`             |
# | Testing    | `X_test`  | `y_test`  | `Y_test`            |

# %%
# function to load features, labels and imagepath from the extraction
def getDataAndImagePaths(model_name, split_type):
    X = pickle.loads(open(f"{FEATURES_OUTPUT_PATH}/{model_name.lower()}_{split_type}_features.pkl", "rb").read())
    y = pickle.loads(open(f"{FEATURES_OUTPUT_PATH}/{model_name.lower()}_{split_type}_labels.pkl", "rb").read())
    imagePaths = pickle.loads(open(f"{FEATURES_OUTPUT_PATH}/{model_name.lower()}_{split_type}_imagepaths.pkl", "rb").read())
    
    return (X, y, imagePaths)

# %% [markdown]
# ## MobileNetV2 with pretrained weights

# %%
model_name = "Cassava_Dataset_MobileNetv2_pretrained"

# load the data from disk
print(f"[INFO] loading training data for {model_name}...")
(data, labels, imagePaths) = getDataAndImagePaths(model_name, split_type = "train")

# splitting the data and label into train validation set
print(f"[INFO] splitting the datasets into train and validation...")
X_train, X_val, y_train, y_val = train_test_split(data, labels, test_size = 0.3, random_state = 42)

# load testing data from disk
print(f"[INFO] loading testing data for {model_name}...")
(X_test, y_test, imagePaths_test) = getDataAndImagePaths(model_name, split_type = "test")
print("[INFO] data loaded...")
# Out:
# [INFO] loading training data for Cassava_Dataset_MobileNetv2_pretrained...
# [INFO] splitting the datasets into train and validation...
# [INFO] loading testing data for Cassava_Dataset_MobileNetv2_pretrained...
# [INFO] data loaded...

# %%
# convert the labels from integers to one-hot-encoded vectors
lb = LabelBinarizer()
Y_train = lb.fit_transform(y_train)
Y_val = lb.transform(y_val)
Y_test = lb.transform(y_test)

# %%
# shape of features
print(X_train.shape)
print(X_val.shape)
print(X_test.shape)
print()

# shape of labels
print(y_train.shape)
print(y_val.shape)
print(y_test.shape)
print()

# shape of labels after encoding
print(Y_train.shape)
print(Y_val.shape)
print(Y_test.shape)
# Out:
# (10486, 294)
# (4494, 294)
# (6417, 294)
#
# (10486,)
# (4494,)
# (6417,)
#
# (10486, 5)
# (4494, 5)
# (6417, 5)

# %% [markdown]
# ### Neural Network Classifier

# %%
from keras.models import Sequential
from keras.layers.core import Dense
from keras.layers import Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam

# %%
input_shape = X_train.shape[1]
print(input_shape)
# Out:
# 294

# %%
model = Sequential()
model.add(Dense(512, input_shape = (input_shape,), activation = "relu"))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(512, activation = "relu"))
model.add(BatchNormalization())
model.add(Dropout(0.25))
model.add(Dense(5, activation="softmax"))

# %%
EPOCHS = 40
BATCH_SIZE = 16

model.compile(loss = "categorical_crossentropy", optimizer = Adam(learning_rate = 0.001), metrics = ["accuracy"])

# %%
# Reduce learning rate when there is a change lesser than <min_delta> in <val_accuracy> for more than <patience> epochs
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor = 'val_accuracy',
                                                 mode = 'max',
                                                 min_delta = 0.01,
                                                 patience = 3,
                                                 factor = 0.25,
                                                 verbose = 1,
                                                 cooldown = 0,
                                                 min_lr = 0.0001)

# Stop the training process when there is a change lesser than <min_delta> in <val_accuracy> for more than <patience> epochs
early_stopper = tf.keras.callbacks.EarlyStopping(monitor = 'val_accuracy',
                                                 mode = 'max',
                                                 min_delta = 0.005,
                                                 patience = 10,
                                                 verbose = 1,
                                                 restore_best_weights = True)

# train the neural network
his_fe = model.fit(X_train, Y_train, validation_data = (X_val, Y_val), epochs = EPOCHS, 
                           batch_size = BATCH_SIZE, callbacks = [early_stopper, reduce_lr])
# Out:
# Epoch 1/40
# 656/656 [==============================] - 6s 7ms/step - loss: 0.9526 - accuracy: 0.6893 - val_loss: 0.9013 - val_accuracy: 0.6947 - lr: 0.0010
# Epoch 2/40
# 656/656 [==============================] - 5s 7ms/step - loss: 0.7439 - accuracy: 0.7295 - val_loss: 0.8755 - val_accuracy: 0.6951 - lr: 0.0010
# Epoch 3/40
# 656/656 [==============================] - 5s 7ms/step - loss: 0.7114 - accuracy: 0.7352 - val_loss: 0.8737 - val_accuracy: 0.6967 - lr: 0.0010
# Epoch 4/40
# 656/656 [==============================] - 5s 7ms/step - loss: 0.6940 - accuracy: 0.7391 - val_loss: 0.8342 - val_accuracy: 0.7074 - lr: 0.0010
# Epoch 5/40
# 656/656 [==============================] - 5s 7ms/step - loss: 0.6913 - accuracy: 0.7397 - val_loss: 0.8224 - val_accuracy: 0.7096 - lr: 0.0010
# Epoch 6/40
# 656/656 [==============================] - 5s 7ms/step - loss: 0.6784 - accuracy: 0.7451 - val_loss: 0.8438 - val_accuracy: 0.7027 - lr: 0.0010
# Epoch 7/40
# 651/656 [============================>.] - ETA: 0s - loss: 0.6701 - accuracy: 0.7475
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 656/656 [==============================] - 4s 6ms/step - loss: 0.6720 - accuracy: 0.7467 - val_loss: 0.8373 - val_accuracy: 0.7052 - lr: 0.0010
# Epoch 8/40
# 656/656 [==============================] - 4s 6ms/step - loss: 0.6372 - accuracy: 0.7572 - val_loss: 0.8074 - val_accuracy: 0.7176 - lr: 2.5000e-04
# Epoch 9/40
# 656/656 [==============================] - 4s 6ms/step - loss: 0.6279 - accuracy: 0.7641 - val_loss: 0.8127 - val_accuracy: 0.7123 - lr: 2.5000e-04
# Epoch 10/40
# 656/656 [==============================] - 4s 6ms/step - loss: 0.6203 - accuracy: 0.7665 - val_loss: 0.8156 - val_accuracy: 0.7150 - lr: 2.5000e-04
# Epoch 11/40
# 652/656 [============================>.] - ETA: 0s - loss: 0.6171 - accuracy: 0.7700
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.0001.
# 656/656 [==============================] - 4s 6ms/step - loss: 0.6176 - accuracy: 0.7697 - val_loss: 0.8047 - val_accuracy: 0.7147 - lr: 2.5000e-04
# Epoch 12/40
# 656/656 [==============================] - 4s 6ms/step - loss: 0.6094 - accuracy: 0.7713 - val_loss: 0.8086 - val_accuracy: 0.7143 - lr: 1.0000e-04
# Epoch 13/40
# 656/656 [==============================] - 4s 6ms/step - loss: 0.6023 - accuracy: 0.7711 - val_loss: 0.8157 - val_accuracy: 0.7132 - lr: 1.0000e-04
# Epoch 14/40
# 656/656 [==============================] - 4s 6ms/step - loss: 0.5949 - accuracy: 0.7750 - val_loss: 0.8176 - val_accuracy: 0.7101 - lr: 1.0000e-04
# Epoch 15/40
# 656/656 [==============================] - 4s 6ms/step - loss: 0.5947 - accuracy: 0.7736 - val_loss: 0.8209 - val_accuracy: 0.7116 - lr: 1.0000e-04
# Epoch 16/40
# 656/656 [==============================] - 4s 6ms/step - loss: 0.5852 - accuracy: 0.7764 - val_loss: 0.8202 - val_accuracy: 0.7143 - lr: 1.0000e-04
# Epoch 17/40
# 656/656 [==============================] - 4s 6ms/step - loss: 0.5804 - accuracy: 0.7802 - val_loss: 0.8305 - val_accuracy: 0.7112 - lr: 1.0000e-04
# Epoch 18/40
# 646/656 [============================>.] - ETA: 0s - loss: 0.5776 - accuracy: 0.7841Restoring model weights from the end of the best epoch: 8.
# 656/656 [==============================] - 4s 6ms/step - loss: 0.5771 - accuracy: 0.7842 - val_loss: 0.8263 - val_accuracy: 0.7130 - lr: 1.0000e-04
# Epoch 18: early stopping

# %%
score = model.evaluate(X_val, Y_val, verbose = 1)
print('Test accuracy:', score[1])
# Out:
# 141/141 [==============================] - 0s 2ms/step - loss: 0.8074 - accuracy: 0.7176
# Test accuracy: 0.7176234722137451

# %%
predy = model.predict(X_test)
pred = np.argmax(predy, axis = 1)
ground = np.argmax(Y_test, axis = 1)
print(classification_report(ground, pred))
# Out:
# 201/201 [==============================] - 0s 2ms/step
#               precision    recall  f1-score   support
#
#            0       0.35      0.25      0.29       326
#            1       0.52      0.56      0.54       656
#            2       0.54      0.27      0.36       715
#            3       0.82      0.92      0.87      3947
#            4       0.46      0.43      0.44       773
#
#     accuracy                           0.71      6417
#    macro avg       0.54      0.48      0.50      6417
# weighted avg       0.69      0.71      0.70      6417

# %%
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
clf_SV = SVC(kernel = 'linear', probability = True)
clf_SV = clf_SV.fit(X_train, np.ravel(y_train))
y_pred = clf_SV.predict(X_test)

print("Accuracy on training set: {:.5f}".format(clf_SV.score(X_train, y_train)))
print("Accuracy on test set:     {:.5f}".format(clf_SV.score(X_test, y_test)))
# Out:
# Accuracy on training set: 0.80097
# Accuracy on test set:     0.70983

# %%
clf_KNN = KNeighborsClassifier(n_neighbors = 60)
clf_KNN = clf_KNN.fit(X_train, np.ravel(y_train))
y_pred = clf_KNN.predict(X_test)

print("Accuracy on training set: {:.5f}".format(clf_KNN.score(X_train, y_train)))
print("Accuracy on test set:     {:.5f}".format(clf_KNN.score(X_test, y_test)))
# Out:
# Accuracy on training set: 0.76140
# Accuracy on test set:     0.70157

# %%
clf_DT = DecisionTreeClassifier(criterion = 'entropy', max_depth = 4, splitter = 'best')
clf_DT = clf_DT.fit(X_train, np.ravel(y_train))
y_pred = clf_DT.predict(X_test)

print("Accuracy on training set: {:.5f}".format(clf_DT.score(X_train, y_train)))
print("Accuracy on test set:     {:.5f}".format(clf_DT.score(X_test, y_test)))
# Out:
# Accuracy on training set: 0.71390
# Accuracy on test set:     0.67695

# %%
clf_RF = RandomForestClassifier(max_depth = 7, random_state = 20)
clf_RF = clf_RF.fit(X_train, np.ravel(y_train))
y_pred = clf_RF.predict(X_test)

print("Accuracy on training set: {:.5f}".format(clf_RF.score(X_train, y_train)))
print("Accuracy on test set:     {:.5f}".format(clf_RF.score(X_test, y_test)))
# Out:
# Accuracy on training set: 0.78915
# Accuracy on test set:     0.70890
